# %% [markdown]
# ## DSND Project1

# %% [markdown]
# #### DataSets Used:
#
# **For this project two datasets were used**
# - Seattle AirBNB Data
# - Boston AirBNB Data

# %% [markdown]
# #### Problem statment:-
# - What features have the highest corrilation with the price
# - Can we generlize that if a property is at a certin location it will effect the price

# %% [markdown]
# ***
# ***

# %%
#Imports
import pandas as pd 
import numpy as np 
import sklearn

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
#pd.set_option('display.max_rows', 20)

# %% [markdown]
# ## Data Understaning

# %% [markdown]
# #### Boston

# %%
#Reading the data
boston_listing = pd.read_csv('data/boston/listings.csv')

# %%
#understanding the data
boston_listing.columns , boston_listing.shape
# Out:
# (Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#         'space', 'description', 'experiences_offered', 'neighborhood_overview',
#         'notes', 'transit', 'access', 'interaction', 'house_rules',
#         'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#         'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#         'host_about', 'host_response_time', 'host_response_rate',
#         'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#         'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#         'host_total_listings_count', 'host_verifications',
#         'host_has_profile_pic', 'host_identity_verified', 'street',
#         'neighbourhood', 'neighbourhood_cleansed',
#         'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#         'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#         'is_location_exact', 'property_type', 'room_type', 'accommodates',
#         'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#         'price', 'weekly_price', 'monthly_price', 'security_deposit',
#         'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#         'maximum_nights', 'calendar_updated', 'has_availability',
#         'availability_30', 'availability_60', 'availability_90',
#         'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#         'first_review', 'last_review', 'review_scores_rating',
#         'review_scores_accuracy', 'review_scores_cleanliness',
#         'review_scores_checkin', 'review_scores_communication',
#         'review_scores_location', 'review_scores_value', 'requires_license',
#         'license', 'jurisdiction_names', 'instant_bookable',
#         'cancellation_policy', 'require_guest_profile_picture',
#         'require_guest_phone_verification', 'calculated_host_listings_count',
#         'reviews_per_month'],
#        dtype='object'),
#  (3585, 95))

# %%
boston_listing.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
boston_listing.isnull().sum()
# Out:
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   756
# Length: 95, dtype: int64

# %%
# make a column to identify the city before merging
boston_listing['city'].fillna('boston',inplace=True)
boston_listing['city'].value_counts()
# Out:
# Boston                       3381
# Roxbury Crossing               24
# Somerville                     19
# Brookline                      18
# Jamaica Plain                  18
# Cambridge                      16
# Dorchester                     15
# Charlestown                    15
# Brighton                       15
# Allston                        12
# Roslindale                      6
# West Roxbury                    5
# ROXBURY CROSSING                4
# boston                          3
# Mattapan                        3
# East Boston                     3
# Boston, Massachusetts, US       2
# ALLSTON                         2
# Jamaica Plain                   2
# South Boston                    2
# Jamaica Plain, Boston           2
# Hyde Park                       2
# dorchester, boston              1
# Jamaica Plain, MA               1
# Mission Hill, Boston            1
# Brighton                        1
# Milton                          1
# Jamaica Plain (Boston)          1
# Jamaica plain                   1
# Newton                          1
# Boston (Charlestown)            1
# Roslindale, Boston              1
# Boston                          1
# east Boston                     1
# Boston (Jamaica Plain)          1
# Watertown                       1
# South End, Boston               1
# 波士顿                             1
# Name: city, dtype: int64

# %% [markdown]
# ### seattle

# %%
seattle_listing = pd.read_csv('data/seattle/listings.csv')

# %%
seattle_listing.columns , seattle_listing.shape
# Out:
# (Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#         'space', 'description', 'experiences_offered', 'neighborhood_overview',
#         'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#         'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#         'host_location', 'host_about', 'host_response_time',
#         'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#         'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#         'host_listings_count', 'host_total_listings_count',
#         'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#         'street', 'neighbourhood', 'neighbourhood_cleansed',
#         'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#         'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#         'is_location_exact', 'property_type', 'room_type', 'accommodates',
#         'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#         'price', 'weekly_price', 'monthly_price', 'security_deposit',
#         'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#         'maximum_nights', 'calendar_updated', 'has_availability',
#         'availability_30', 'availability_60', 'availability_90',
#         'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#         'first_review', 'last_review', 'review_scores_rating',
#         'review_scores_accuracy', 'review_scores_cleanliness',
#         'review_scores_checkin', 'review_scores_communication',
#         'review_scores_location', 'review_scores_value', 'requires_license',
#         'license', 'jurisdiction_names', 'instant_bookable',
#         'cancellation_policy', 'require_guest_profile_picture',
#         'require_guest_phone_verification', 'calculated_host_listings_count',
#         'reviews_per_month'],
#        dtype='object'),
#  (3818, 92))

# %%
seattle_listing.isnull().sum()
# Out:
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   627
# Length: 92, dtype: int64

# %%
# make a column to identify the city before merging
seattle_listing['city'].fillna('seattle',inplace=True)
seattle_listing['city'].value_counts()
# Out:
# Seattle                  3810
# Seattle                     2
# West Seattle                2
# Phinney Ridge Seattle       1
# Ballard, Seattle            1
# 西雅图                         1
# seattle                     1
# Name: city, dtype: int64

# %%
# visulizing the missing values before merging
def missing_heat_map(DataFrame):
        import numpy as np
        import pandas as pd
        import seaborn as sns
        import matplotlib.pyplot as plt
        sns.set_style('whitegrid')
        
        
    # plot the missing values
        fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (18, 6))
        sns.heatmap(DataFrame.isnull(), yticklabels=False, ax = ax, cbar=False, cmap='viridis')
        ax.set_title('dataset')
        plt.show()
        
    # Calculate the missing values to get a percentage 

        for i in DataFrame:
            print(i,': %',int((DataFrame[i].isnull().sum()/len(DataFrame[i]))*100),\
                  'With {} missing values'.format((DataFrame[i].isnull().sum())))

# %%
# Understand the missing values for seattle dataset
missing_heat_map(seattle_listing)
# Out:
# id : % 0 With 0 missing values
# listing_url : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# summary : % 4 With 177 missing values
# space : % 14 With 569 missing values
# description : % 0 With 0 missing values
# experiences_offered : % 0 With 0 missing values
# neighborhood_overview : % 27 With 1032 missing values
# notes : % 42 With 1606 missing values
# transit : % 24 With 934 missing values
# thumbnail_url : % 8 With 320 missing values
# medium_url : % 8 With 320 missing values
# picture_url : % 0 With 0 missing values
# xl_picture_url : % 8 With 320 missing values
# host_id : % 0 With 0 missing values
# host_url : % 0 With 0 missing values
# host_name : % 0 With 2 missing values
# host_since : % 0 With 2 missing values
# host_location : % 0 With 8 missing values
# host_about : % 22 With 859 missing values
# host_response_time : % 13 With 523 missing values
# host_response_rate : % 13 With 523 missing values
# host_acceptance_rate : % 20 With 773 missing values
# host_is_superhost : % 0 With 2 missing values
# host_thumbnail_url : % 0 With 2 missing values
# host_picture_url : % 0 With 2 missing values
# host_neighbourhood : % 7 With 300 missing values
# host_listings_count : % 0 With 2 missing values
# host_total_listings_count : % 0 With 2 missing values
# host_verifications : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 2 missing values
# host_identity_verified : % 0 With 2 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 10 With 416 missing values
# neighbourhood_cleansed : % 0 With 0 missing values
# neighbourhood_group_cleansed : % 0 With 0 missing values
# city : % 0 With 0 missing values
# state : % 0 With 0 missing values
# zipcode : % 0 With 7 missing values
# market : % 0 With 0 missing values
# smart_location : % 0 With 0 missing values
# country_code : % 0 With 0 missing values
# country : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 1 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 16 missing values
# bedrooms : % 0 With 6 missing values
# beds : % 0 With 1 missing values
# bed_type : % 0 With 0 missing values
# amenities : % 0 With 0 missing values
# square_feet : % 97 With 3721 missing values
# price : % 0 With 0 missing values
# weekly_price : % 47 With 1809 missing values
# monthly_price : % 60 With 2301 missing values
# security_deposit : % 51 With 1952 missing values
# cleaning_fee : % 26 With 1030 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 0 With 0 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 16 With 627 missing values
# last_review : % 16 With 627 missing values
# review_scores_rating : % 16 With 647 missing values
# review_scores_accuracy : % 17 With 658 missing values
# review_scores_cleanliness : % 17 With 653 missing values
# review_scores_checkin : % 17 With 658 missing values
# review_scores_communication : % 17 With 651 missing values
# review_scores_location : % 17 With 655 missing values
# review_scores_value : % 17 With 656 missing values
# requires_license : % 0 With 0 missing values
# license : % 100 With 3818 missing values
# jurisdiction_names : % 0 With 0 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 16 With 627 missing values

# %%
# Understand the missing values for the boston dataset
missing_heat_map(boston_listing)
# Out:
# id : % 0 With 0 missing values
# listing_url : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# summary : % 3 With 143 missing values
# space : % 29 With 1057 missing values
# description : % 0 With 0 missing values
# experiences_offered : % 0 With 0 missing values
# neighborhood_overview : % 39 With 1415 missing values
# notes : % 55 With 1975 missing values
# transit : % 35 With 1290 missing values
# access : % 41 With 1489 missing values
# interaction : % 43 With 1554 missing values
# house_rules : % 33 With 1192 missing values
# thumbnail_url : % 16 With 599 missing values
# medium_url : % 16 With 599 missing values
# picture_url : % 0 With 0 missing values
# xl_picture_url : % 16 With 599 missing values
# host_id : % 0 With 0 missing values
# host_url : % 0 With 0 missing values
# host_name : % 0 With 0 missing values
# host_since : % 0 With 0 missing values
# host_location : % 0 With 11 missing values
# host_about : % 36 With 1309 missing values
# host_response_time : % 13 With 471 missing values
# host_response_rate : % 13 With 471 missing values
# host_acceptance_rate : % 13 With 471 missing values
# host_is_superhost : % 0 With 0 missing values
# host_thumbnail_url : % 0 With 0 missing values
# host_picture_url : % 0 With 0 missing values
# host_neighbourhood : % 9 With 339 missing values
# host_listings_count : % 0 With 0 missing values
# host_total_listings_count : % 0 With 0 missing values
# host_verifications : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 0 missing values
# host_identity_verified : % 0 With 0 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 15 With 543 missing values
# neighbourhood_cleansed : % 0 With 0 missing values
# neighbourhood_group_cleansed : % 100 With 3585 missing values
# city : % 0 With 0 missing values
# state : % 0 With 0 missing values
# zipcode : % 1 With 38 missing values
# market : % 0 With 14 missing values
# smart_location : % 0 With 0 missing values
# country_code : % 0 With 0 missing values
# country : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 3 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 14 missing values
# bedrooms : % 0 With 10 missing values
# beds : % 0 With 9 missing values
# bed_type : % 0 With 0 missing values
# amenities : % 0 With 0 missing values
# square_feet : % 98 With 3529 missing values
# price : % 0 With 0 missing values
# weekly_price : % 75 With 2693 missing values
# monthly_price : % 75 With 2697 missing values
# security_deposit : % 62 With 2243 missing values
# cleaning_fee : % 30 With 1107 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 100 With 3585 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 21 With 756 missing values
# last_review : % 21 With 756 missing values
# review_scores_rating : % 22 With 813 missing values
# review_scores_accuracy : % 22 With 823 missing values
# review_scores_cleanliness : % 22 With 818 missing values
# review_scores_checkin : % 22 With 820 missing values
# review_scores_communication : % 22 With 818 missing values
# review_scores_location : % 22 With 822 missing values
# review_scores_value : % 22 With 821 missing values
# requires_license : % 0 With 0 missing values
# license : % 100 With 3585 missing values
# jurisdiction_names : % 100 With 3585 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 21 With 756 missing values

# %%
# get the column list that is in both datasets
column_list = set(seattle_listing.columns).intersection(boston_listing.columns)
column_list = list(column_list)

# %%
# check that the columns match before merging the two datasets 

# get the unique columns in the seattle dataset
seattle_unique = [x for x in seattle_listing if x not in column_list]
print(seattle_unique)

# get the unique columns in the boston_ls dataset
boston_unique = [x for x in boston_listing if x not in column_list]
print(boston_unique)
# Out:
# []
# ['access', 'interaction', 'house_rules']

# %% [markdown]
# **This means that both datasets don't have column naming issues**

# %%
#Checking the unique columns in the boston dataset
boston_listing[['access','interaction','house_rules']].isnull().sum()
# Out:
# access         1489
# interaction    1554
# house_rules    1192
# dtype: int64

# %%
# merge both datasets for an esier cleaning process
df = pd.concat([seattle_listing,boston_listing],ignore_index=True)

# %%
df.shape
# Out:
# (7403, 95)

# %%
missing_heat_map(df)
# Out:
# id : % 0 With 0 missing values
# listing_url : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# summary : % 4 With 320 missing values
# space : % 21 With 1626 missing values
# description : % 0 With 0 missing values
# experiences_offered : % 0 With 0 missing values
# neighborhood_overview : % 33 With 2447 missing values
# notes : % 48 With 3581 missing values
# transit : % 30 With 2224 missing values
# thumbnail_url : % 12 With 919 missing values
# medium_url : % 12 With 919 missing values
# picture_url : % 0 With 0 missing values
# xl_picture_url : % 12 With 919 missing values
# host_id : % 0 With 0 missing values
# host_url : % 0 With 0 missing values
# host_name : % 0 With 2 missing values
# host_since : % 0 With 2 missing values
# host_location : % 0 With 19 missing values
# host_about : % 29 With 2168 missing values
# host_response_time : % 13 With 994 missing values
# host_response_rate : % 13 With 994 missing values
# host_acceptance_rate : % 16 With 1244 missing values
# host_is_superhost : % 0 With 2 missing values
# host_thumbnail_url : % 0 With 2 missing values
# host_picture_url : % 0 With 2 missing values
# host_neighbourhood : % 8 With 639 missing values
# host_listings_count : % 0 With 2 missing values
# host_total_listings_count : % 0 With 2 missing values
# host_verifications : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 2 missing values
# host_identity_verified : % 0 With 2 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 12 With 959 missing values
# neighbourhood_cleansed : % 0 With 0 missing values
# neighbourhood_group_cleansed : % 48 With 3585 missing values
# city : % 0 With 0 missing values
# state : % 0 With 0 missing values
# zipcode : % 0 With 45 missing values
# market : % 0 With 14 missing values
# smart_location : % 0 With 0 missing values
# country_code : % 0 With 0 missing values
# country : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 4 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 30 missing values
# bedrooms : % 0 With 16 missing values
# beds : % 0 With 10 missing values
# bed_type : % 0 With 0 missing values
# amenities : % 0 With 0 missing values
# square_feet : % 97 With 7250 missing values
# price : % 0 With 0 missing values
# weekly_price : % 60 With 4502 missing values
# monthly_price : % 67 With 4998 missing values
# security_deposit : % 56 With 4195 missing values
# cleaning_fee : % 28 With 2137 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 48 With 3585 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 18 With 1383 missing values
# last_review : % 18 With 1383 missing values
# review_scores_rating : % 19 With 1460 missing values
# review_scores_accuracy : % 20 With 1481 missing values
# review_scores_cleanliness : % 19 With 1471 missing values
# review_scores_checkin : % 19 With 1478 missing values
# review_scores_communication : % 19 With 1469 missing values
# review_scores_location : % 19 With 1477 missing values
# review_scores_value : % 19 With 1477 missing values
# requires_license : % 0 With 0 missing values
# license : % 100 With 7403 missing values
# jurisdiction_names : % 48 With 3585 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 18 With 1383 missing values
# access : % 71 With 5307 missing values
# interaction : % 72 With 5372 missing values
# house_rules : % 67 With 5010 missing values

# %%
df.dtypes
# Out:
# id                                  int64
# listing_url                        object
# scrape_id                           int64
# last_scraped                       object
# name                               object
#                                    ...
# calculated_host_listings_count      int64
# reviews_per_month                 float64
# access                             object
# interaction                        object
# house_rules                        object
# Length: 95, dtype: object

# %%
df.to_csv('full_data.csv')

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Data prepreation

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7403 entries, 0 to 7402
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                7403 non-null   int64
#  1   listing_url                       7403 non-null   object
#  2   scrape_id                         7403 non-null   int64
#  3   last_scraped                      7403 non-null   object
#  4   name                              7403 non-null   object
#  5   summary                           7083 non-null   object
#  6   space                             5777 non-null   object
#  7   description                       7403 non-null   object
#  8   experiences_offered               7403 non-null   object
#  9   neighborhood_overview             4956 non-null   object
#  10  notes                             3822 non-null   object
#  11  transit                           5179 non-null   object
#  12  thumbnail_url                     6484 non-null   object
#  13  medium_url                        6484 non-null   object
#  14  picture_url                       7403 non-null   object
#  15  xl_picture_url                    6484 non-null   object
#  16  host_id                           7403 non-null   int64
#  17  host_url                          7403 non-null   object
#  18  host_name                         7401 non-null   object
#  19  host_since                        7401 non-null   object
#  20  host_location                     7384 non-null   object
#  21  host_about                        5235 non-null   object
#  22  host_response_time                6409 non-null   object
#  23  host_response_rate                6409 non-null   object
#  24  host_acceptance_rate              6159 non-null   object
#  25  host_is_superhost                 7401 non-null   object
#  26  host_thumbnail_url                7401 non-null   object
#  27  host_picture_url                  7401 non-null   object
#  28  host_neighbourhood                6764 non-null   object
#  29  host_listings_count               7401 non-null   float64
#  30  host_total_listings_count         7401 non-null   float64
#  31  host_verifications                7403 non-null   object
#  32  host_has_profile_pic              7401 non-null   object
#  33  host_identity_verified            7401 non-null   object
#  34  street                            7403 non-null   object
#  35  neighbourhood                     6444 non-null   object
#  36  neighbourhood_cleansed            7403 non-null   object
#  37  neighbourhood_group_cleansed      3818 non-null   object
#  38  city                              7403 non-null   object
#  39  state                             7403 non-null   object
#  40  zipcode                           7358 non-null   object
#  41  market                            7389 non-null   object
#  42  smart_location                    7403 non-null   object
#  43  country_code                      7403 non-null   object
#  44  country                           7403 non-null   object
#  45  latitude                          7403 non-null   float64
#  46  longitude                         7403 non-null   float64
#  47  is_location_exact                 7403 non-null   object
#  48  property_type                     7399 non-null   object
#  49  room_type                         7403 non-null   object
#  50  accommodates                      7403 non-null   int64
#  51  bathrooms                         7373 non-null   float64
#  52  bedrooms                          7387 non-null   float64
#  53  beds                              7393 non-null   float64
#  54  bed_type                          7403 non-null   object
#  55  amenities                         7403 non-null   object
#  56  square_feet                       153 non-null    float64
#  57  price                             7403 non-null   object
#  58  weekly_price                      2901 non-null   object
#  59  monthly_price                     2405 non-null   object
#  60  security_deposit                  3208 non-null   object
#  61  cleaning_fee                      5266 non-null   object
#  62  guests_included                   7403 non-null   int64
#  63  extra_people                      7403 non-null   object
#  64  minimum_nights                    7403 non-null   int64
#  65  maximum_nights                    7403 non-null   int64
#  66  calendar_updated                  7403 non-null   object
#  67  has_availability                  3818 non-null   object
#  68  availability_30                   7403 non-null   int64
#  69  availability_60                   7403 non-null   int64
#  70  availability_90                   7403 non-null   int64
#  71  availability_365                  7403 non-null   int64
#  72  calendar_last_scraped             7403 non-null   object
#  73  number_of_reviews                 7403 non-null   int64
#  74  first_review                      6020 non-null   object
#  75  last_review                       6020 non-null   object
#  76  review_scores_rating              5943 non-null   float64
#  77  review_scores_accuracy            5922 non-null   float64
#  78  review_scores_cleanliness         5932 non-null   float64
#  79  review_scores_checkin             5925 non-null   float64
#  80  review_scores_communication       5934 non-null   float64
#  81  review_scores_location            5926 non-null   float64
#  82  review_scores_value               5926 non-null   float64
#  83  requires_license                  7403 non-null   object
#  84  license                           0 non-null      float64
#  85  jurisdiction_names                3818 non-null   object
#  86  instant_bookable                  7403 non-null   object
#  87  cancellation_policy               7403 non-null   object
#  88  require_guest_profile_picture     7403 non-null   object
#  89  require_guest_phone_verification  7403 non-null   object
#  90  calculated_host_listings_count    7403 non-null   int64
#  91  reviews_per_month                 6020 non-null   float64
#  92  access                            2096 non-null   object
#  93  interaction                       2031 non-null   object
#  94  house_rules                       2393 non-null   object
# dtypes: float64(17), int64(13), object(65)
# memory usage: 5.4+ MB

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**listing_url**|`object`|Delete since URL not needed|
# |**picture_url**|`object`|Delete since URL not needed|
# |**xl_picture_url**|`object`|Delete since URL not needed|
# |**host_url**|`object`|Delete since URL not needed|
# |**host_thumbnail_url**|`object`|Delete since URL not needed|
# |**medium_url**|`object`|Delete since URL not needed|
# |**thumbnail_url**|`object`|Delete since URL not needed|
# |**host_picture_url**|`object`|Delete since URL not needed|
# |**square_feet**|`float64`|remove since %97 percent of data is missing|
# |**license**|`NaN`|remove since %100 percent of data is missing|

# %%
# removing some unnessary columns(rest will be removed later)
del df['listing_url']
del df['picture_url']
del df['xl_picture_url']
del df['host_url']
del df['host_thumbnail_url']
del df['medium_url']
del df['thumbnail_url']
del df['host_picture_url']
del df['license']
del df['square_feet']

# %%
df.isnull().sum()
# Out:
# id                                   0
# scrape_id                            0
# last_scraped                         0
# name                                 0
# summary                            320
#                                   ...
# calculated_host_listings_count       0
# reviews_per_month                 1383
# access                            5307
# interaction                       5372
# house_rules                       5010
# Length: 85, dtype: int64

# %% [markdown]
# **Now I will try to go through each column and evaluate it**

# %% [markdown]
# **Since I will not choose an NLP approch.I will extract the number of words each of these strings and replace the column which might serve as a feature worth exploring**
#
# |Feature|Type|Action|
# |---|---|---|
# |**summary**|`object`|Get the word count insted|
# |**space**|`object`|Get the word count insted|
# |**description**|`object`|Get the word count insted|
# |**neighborhood_overview**|`object`|Get the word count insted|
# |**transit**|`object`|Get the word count insted|
# |**host_about**|`object`|Get the word count insted|
# |**notes**|`object`|Get the word count insted|
# |**host_about**|`object`|Get the word count insted|

# %%
def get_wordcount(column,df=df):
    return df[str(column)].apply(lambda x : len(x.split(' ')) if type(x) == str else 0)

# %%
# calculate the wordcount of the columns above and apply it to new columns
df['summary_wc'] = get_wordcount('summary')
df['space_wc'] = get_wordcount('space')
df['description_wc'] = get_wordcount('description')
df['neighborhood_overview_wc'] = get_wordcount('neighborhood_overview')
df['transit_wc'] = get_wordcount('transit')
df['host_about_wc'] = get_wordcount('host_about')
df['notes_wc'] = get_wordcount('notes')

# %%
# delete the columns 
del df['summary']
del df['space']
del df['description']
del df['neighborhood_overview']
del df['transit']
del df['host_about']
del df['notes']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**experiences_offered**|`object`|delete since all values are none|

# %%
# check column 
df['experiences_offered'].head()
# Out:
# 0    none
# 1    none
# 2    none
# 3    none
# 4    none
# Name: experiences_offered, dtype: object

# %%
#check values
df['experiences_offered'].value_counts()
# Out:
# none    7403
# Name: experiences_offered, dtype: int64

# %%
#delete column
del df['experiences_offered']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**host_location**|`object`|clean|
# |**smart_location**|`object`|clean|
# |**city**|`object`|delete to avoid redundency|
# |**zipcode**|`object`|clean|
# |**state**|`object`|delete to avoid redundency|
# |**country**|`object`|delete to avoid redundency|
# |**street**|`object`|clean|
# |**neighbourhood**|`object`|clean|
# |**country_code**|`object`|delete to avoid redundency|
# |**latitude**|`Float`|clean|
# |**longitude**|`Float`|clean|
# |**is_location_exact**|`object`|clean|

# %%
df[['host_location','smart_location','city','state','country','country_code','is_location_exact']]
# Out:
#      host_location smart_location        city state        country  \
# 0          Seattle        Seattle     Seattle    WA  United States
# 1          Seattle        Seattle     Seattle    WA  United States
# 2          Seattle        Seattle     Seattle    WA  United States
# 3          Seattle        Seattle     Seattle    WA  United States
# 4          Seattle        Seattle     Seattle    WA  United States
# ...            ...            ...         ...   ...            ...
# 7398    Somerville     Somerville  Somerville    MA  United States
# 7399            US      Brookline   Brookline    MA  United States
# 7400           New      Cambridge   Cambridge    MA  United States
# 7401    Somerville     Somerville  Somerville    MA  United States
# 7402    Somerville     Somerville  Somerville    MA  United States
#
#      country_code is_location_exact
# 0              US                 t
# 1              US                 t
# 2              US                 t
# 3              US                 t
# 4              US                 t
# ...           ...               ...
# 7398           US                 t
# 7399           US                 f
# 7400           US                 f
# 7401           US                 t
# 7402           US                 t
#
# [7403 rows x 7 columns]

# %% [markdown]
# **split the locations to get the city only which will reduce the value count and help with matching the host location to the property location**

# %%
#split the host_location to get only the city
df['host_location'] = df['host_location'].apply(lambda x : x.split(',')[0].split(' ')[0] if type(x) == str else 'unknown')
#split the property location to get only the city
df['smart_location'] = df['smart_location'].apply(lambda x : x.split(',')[0].split(' ')[0] if type(x) == str else 'unknown')

# %% [markdown]
# **check weather the host lives in the same city of the property or not**

# %%
#compare if the columns are equal put 1 else 0
df['host_match'] = np.where(df['host_location'] == df['smart_location'], 1, 0)

# %%
df['host_match'].value_counts()
# Out:
# 1    5598
# 0    1805
# Name: host_match, dtype: int64

# %%
#group by host_id to check listing count
grouped_host = df[['host_id','host_name','host_since','host_location','host_listings_count']].groupby('host_id')
for key, item in grouped_host:
    print(grouped_host.get_group(key), "\n\n")
# Out:
#       host_id host_name  host_since host_location  host_listings_count
# 2184     4193   Jessica  2008-11-10       Seattle                  4.0
# 2190     4193   Jessica  2008-11-10       Seattle                  4.0
# 2192     4193   Jessica  2008-11-10       Seattle                  4.0
# 2194     4193   Jessica  2008-11-10       Seattle                  4.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 7125     4240  Giuseppe  2008-11-11        Boston                  6.0
# 7341     4240  Giuseppe  2008-11-11        Boston                  6.0
#
#
#       host_id host_name  host_since  host_location  host_listings_count
# 5362     4804     Frank  2008-12-03  Massachusetts                  5.0
#
#
#       host_id      host_name  host_since host_location  host_listings_count
# 1413     6207  Cory & Amanda  2009-01-08       Seattle                  1.0
#
#
#       host_id                     host_name  host_since host_location  \
# 2978     8021                         Becky  2009-02-16        Boston
# 3020     8021                         Becky  2009-02-16        Boston
# 3949     8021  L&B (Len & Becky Or Blenky*)  2009-02-16       Seattle
#
#       host_listings_count
# 2978                  4.0
# 3020                  4.0
# 3949                  5.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 
  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 965    68641    Angela  2010-01-07       Seattle                  1.0
#
#
#       host_id     host_name  host_since host_location  host_listings_count
# 5441    68870  Jim & Afiyah  2010-01-08        Boston                  3.0
# 5476    68870  Jim & Afiyah  2010-01-08        Boston                  3.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6274    71783     Lance  2010-01-19        Boston                 10.0
# 6499    71783     Lance  2010-01-19        Boston                 10.0
# 6742    71783     Lance  2010-01-19        Boston                 10.0
# 6753    71783     Lance  2010-01-19        Boston                 10.0
# 6755    71783     Lance  2010-01-19        Boston                 10.0
# 6763    71783     Lance  2010-01-19        Boston                 10.0
# 6784    71783     Lance  2010-01-19        Boston                 10.0
# 6787    71783     Lance  2010-01-19        Boston                 10.0
# 6804    71783     Lance  2010-01-19        Boston                 10.0
# 6834    71783     Lance  2010-01-19        Boston                 10.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2147    73359      Mary  2010-01-25       Seattle                  2.0
# 2156    73359      Mary  2010-01-25       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 498     74305     Darik  2010-01-27          Kent                 34.0
# 1086    74305     Darik  2010-01-27          Kent                 34.0
# 1210    74305     Darik  2010-01-27          Kent                 34.0
# 1239    74305     Darik  2010-01-27          Kent                 34.0
# 1242    74305     Darik  2010-01-27          Kent                 34.0
# 1244    74305     Darik  2010-01-27          Kent                 34.0
# 1282    74305     Darik  2010-01-27          Kent                 34.0
# 1288    74305     Darik  2010-01-27          Kent                 34.0
# 1289    74305     Darik  2010-01-27          Kent                 34.0
# 1290    74305     Darik  2010-01-27          Kent                 34.0
# 1291    74305     Darik  2010-01-27          Kent                 34.0
# 1306    74305     Darik  2010-01-27          Kent                 34.0
# 1307    74305     Darik  2010-01-27          Kent                 34.0
# 1308    74305     Darik  2010-01-27          Kent                 34.0
# 1309    74305     Darik  2010-01-27          Kent                 34.0
# 1314    74305     Darik  2010-01-27          Kent                 34.0
# 1320    74305     Darik  2010-01-27          Kent                 34.0
# 1328    74305     Darik  2010-01-27          Kent                 34.0
# 1331    74305     Darik  2010-01-27          Kent                 34.0
# 1339    74305     Darik  2010-01-27          Kent                 34.0
# 1350    74305     Darik  2010-01-27          Kent                 34.0
# 1352    74305     Darik  2010-01-27          Kent                 34.0
# 1354    74305     Darik  2010-01-27          Kent                 34.0
# 1357    74305     Darik  2010-01-27          Kent                 34.0
# 1362    74305     Darik  2010-01-27          Kent                 34.0
# 1370    74305     Darik  2010-01-27          Kent                 34.0
# 1395    74305     Darik  2010-01-27          Kent                 34.0
# 1403    74305     Darik  2010-01-27          Kent                 34.0
# 1426    74305     Darik  2010-01-27          Kent                 34.0
# 1428    74305     Darik  2010-01-27          Kent                 34.0
# 1531    74305     Darik  2010-01-27          Kent                 34.0
# 1570    74305     Darik  2010-01-27          Kent                 34.0
# 1605    74305     Darik  2010-01-27          Kent                 34.0
#
#
#      host_id   host_name  host_since host_location  host_listings_count
# 96     79450  Brad & Liz  2010-02-09       Seattle                  2.0
# 126    79450  Brad & Liz  2010-02-09       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3347    83099      Cass  2010-02-19       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4750    85770    Robert  2010-02-26        Boston                  5.0
# 4807    85770    Robert  2010-02-26        Boston                  5.0
# 4938    85770    Robert  2010-02-26        Boston                  5.0
# 4955    85770    Robert  2010-02-26        Boston                  5.0
# 4991    85770    Robert  2010-02-26        Boston                  5.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3633    86885    Monica  2010-03-01       Seattle                  1.0
#
#
#       host_id         host_name  host_since host_location  host_listings_count
# 3563    87587  Margot & Anthony  2010-03-02       Seattle                  4.0
# 3638    87587  Margot & Anthony  2010-03-02       Seattle                  4.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2782    90437       Ian  2010-03-09       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2053    91286   Tonyhai  2010-03-11       Seattle                  2.0
#
#
#       host_id       host_name  host_since host_location  host_listings_count
# 5777    93112  Henry And Lisa  2010-03-14        Boston                  6.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5436    93916  Francine  2010-03-15        Boston                  2.0
# 5479    93916  Francine  2010-03-15        Boston                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3421    95510     Peggy  2010-03-18       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4662    95959   Bandita  2010-03-19        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4848    97805   Stephen  2010-03-23        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4512    97821  Gretchen  2010-03-23            CA                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3083   102684    Amanda  2010-04-02       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1492   103427   Magalie  2010-04-04          West                 84.0
# 1495   103427   Magalie  2010-04-04          West                 84.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2838   106700       Zvi  2010-04-11       Seattle                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 214   106721     Paula  2010-04-11       Seattle                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 256   106972     Kelly  2010-04-11       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1453   107542    Arthur  2010-04-12       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3006   107605        Al  2010-04-12       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2325   110120   Melissa  2010-04-18       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2945   110248   Jamilah  2010-04-18       Seattle                  1.0
#
#
#       host_id     host_name  host_since host_location  host_listings_count
# 1858   110917  Erin & Vince  2010-04-19       Seattle                  1.0
#
#
#       host_id      host_name  host_since host_location  host_listings_count
# 3316   112093  Roberta & Dan  2010-04-21       Seattle                  1.0
#
#
#       host_id      host_name  host_since host_location  host_listings_count
# 4036   113091  Nina And Mike  2010-04-24        Boston                  1.0
#
#
#       host_id        host_name  host_since host_location  host_listings_count
# 6661   115522  Nate + Danielle  2010-04-29        Boston                  2.0
# 6811   115522  Nate + Danielle  2010-04-29        Boston                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6603   119019   Hermina  2010-05-05        Boston                 11.0
# 6611   119019   Hermina  2010-05-05        Boston                 11.0
# 6613   119019   Hermina  2010-05-05        Boston                 11.0
# 6627   119019   Hermina  2010-05-05        Boston                 11.0
# 6629   119019   Hermina  2010-05-05        Boston                 11.0
# 6639   119019   Hermina  2010-05-05        Boston                 11.0
# 6723   119019   Hermina  2010-05-05        Boston                 11.0
# 6786   119019   Hermina  2010-05-05        Boston                 11.0
# 6832   119019   Hermina  2010-05-05        Boston                 11.0
#
#
#       host_id             host_name  host_since host_location  \
# 3984   119381  Gordon And Alexandra  2010-05-06        Boston
#
#       host_listings_count
# 3984                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1292   119809     Weisi  2010-05-07       Seattle                  1.0
#
#
#       host_id       host_name  host_since host_location  host_listings_count
# 4133   120731  Adrian Nichola  2010-05-08        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5520   122982    Nadine  2010-05-11        Boston                  1.0
#
#
#       host_id  host_name  host_since host_location  host_listings_count
# 5518   128280  Elizabeth  2010-05-19        Boston                  4.0
# 5538   128280  Elizabeth  2010-05-19        Boston                  4.0
# 5591   128280  Elizabeth  2010-05-19        Boston                  4.0
#
#
#      host_id      host_name  host_since host_location  host_listings_count
# 138   129014  Rob And Molly  2010-05-20       Seattle                  2.0
# 167   129014  Rob And Molly  2010-05-20       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2936   149118      Bart  2010-06-21       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2035   157262    Visala  2010-07-02       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5195   157679      Sara  2010-07-03        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6228   159160   Deborah  2010-07-06        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2995   160789   Darrell  2010-07-08       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1037   164430      Jill  2010-07-12      Kirkland                  3.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 409    165390      Seth  2010-07-13       Seattle                  5.0
# 423    165390      Seth  2010-07-13       Seattle                  5.0
# 3674   165390      Seth  2010-07-13       Seattle                  5.0
# 3753   165390      Seth  2010-07-13       Seattle                  5.0
# 3771   165390      Seth  2010-07-13       Seattle                  5.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3496   167482       Ann  2010-07-15       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6033   167745    Angela  2010-07-15        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3378   168580      Glyn  2010-07-16       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4731   170480     Chloe  2010-07-18           New                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4050   174986    Robert  2010-07-20        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1801   178552   Rebecca  2010-07-23       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5893   178829      John  2010-07-23     Braintree                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3469   179030   Harriet  2010-07-24       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 168    179626     Susan  2010-07-24       Seattle                  2.0
# 3784   179626     Susan  2010-07-24       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1931   180441      Pina  2010-07-25       Seattle                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 328   181621   Barbara  2010-07-26       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5038   183065    Laurel  2010-07-28        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6075   184232    Ashley  2010-07-29        Boston                  2.0
# 6122   184232    Ashley  2010-07-29        Boston                  2.0
#
#
#      host_id       host_name  host_since host_location  host_listings_count
# 382   184382  Harry & Amanda  2010-07-29       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3554   186257    Nicole  2010-07-30       Seattle                  1.0
#
#
#       host_id         host_name  host_since host_location  host_listings_count
# 2456   187753  Kevin & Jennifer  2010-08-01       Seattle                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 351   189356   Michael  2010-08-02       Seattle                  1.0
#
#
#       host_id    host_name  host_since host_location  host_listings_count
# 4724   189855  Marla & Coe  2010-08-03        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1788   192355      Jane  2010-08-05       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2107   193689      Eric  2010-08-06       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4112   197327   Melissa  2010-08-10        Boston                  2.0
# 4155   197327   Melissa  2010-08-10        Boston                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3276   197690  Trishann  2010-08-10       Seattle                  3.0
# 3652   197690  Trishann  2010-08-10       Seattle                  3.0
# 3654   197690  Trishann  2010-08-10       Seattle                  3.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5374   204485    DeAnna  2010-08-17        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1682   204975  Philippe  2010-08-18       Seattle                  1.0
#
#
#     host_id         host_name  host_since host_location  host_listings_count
# 95   205007  Martin And Taryn  2010-08-18       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5524   205107      Atef  2010-08-18        Boston                  2.0
# 5541   205107      Atef  2010-08-18        Boston                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1863   205325      Teri  2010-08-18       Seattle                  3.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1861   205412       Meg  2010-08-18    Washington                 10.0
# 1864   205412       Meg  2010-08-18    Washington                 10.0
# 1873   205412       Meg  2010-08-18    Washington                 10.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3999   206353     Perry  2010-08-19        Boston                  8.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5129   206505    Cecile  2010-08-19        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3228   207419   Hayoung  2010-08-20       Seattle                  1.0
#
#
#       host_id       host_name  host_since host_location  host_listings_count
# 3881   207475  Danielle&Peder  2010-08-20        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3442   208959       Val  2010-08-22       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1177   209571    Cheryl  2010-08-22       Seattle                  1.0
#
#
#       host_id     host_name  host_since host_location  host_listings_count
# 3417   212404  Piper + Kent  2010-08-25       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4622   212445      Emma  2010-08-25     Cambridge                  6.0
# 4627   212445      Emma  2010-08-25     Cambridge                  6.0
# 4708   212445      Emma  2010-08-25     Cambridge                  6.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3600   212740   Shalini  2010-08-25       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3234   215230     Carol  2010-08-28       Seattle                  4.0
# 3243   215230     Carol  2010-08-28       Seattle                  4.0
# 3246   215230     Carol  2010-08-28       Seattle                  4.0
# 3249   215230     Carol  2010-08-28       Seattle                  4.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1151   220013      Erik  2010-09-01       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1100   222538     Suryo  2010-09-03       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4236   224090    Tricia  2010-09-04        Boston                  1.0
#
#
#       host_id    host_name  host_since host_location  host_listings_count
# 3027   225830  Lee & Steve  2010-09-06       Seattle                  2.0
# 3029   225830  Lee & Steve  2010-09-06       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1135   225845     Gavin  2010-09-06       Seattle                  2.0
# 2558   225845     Gavin  2010-09-06       Seattle                  2.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 777   228678     Katie  2010-09-08       Seattle                  1.0
#
#
#       host_id host_name  host_since          host_location  \
# 4197   228845    Jeremy  2010-09-08  Manchester-by-the-Sea
# 4209   228845    Jeremy  2010-09-08  Manchester-by-the-Sea
#
#       host_listings_count
# 4197                  5.0
# 4209                  5.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1891   230140     Marie  2010-09-10       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2237   236709     Mandy  2010-09-16       Seattle                  2.0
# 2245   236709     Mandy  2010-09-16       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4037   236790       Ann  2010-09-16        Boston                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 228   238431     Brian  2010-09-18       Seattle                  1.0
#
#
#       host_id       host_name  host_since host_location  host_listings_count
# 3667   238982  Maria & Graham  2010-09-19           San                  7.0
# 3694   238982  Maria & Graham  2010-09-19           San                  7.0
# 3786   238982  Maria & Graham  2010-09-19           San                  7.0
#
#
#     host_id     host_name  host_since host_location  host_listings_count
# 10   239585  Ray & Eileen  2010-09-19       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6838   239850  Theodore  2010-09-20        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3497   242188  Jennifer  2010-09-22       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4304   246083   Lindsey  2010-09-26           New                  1.0
#
#
#       host_id         host_name  host_since host_location  host_listings_count
# 1545   247975  Kevin And Monica  2010-09-28       Seattle                  2.0
# 2420   247975  Kevin And Monica  2010-09-28       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4614   255183  Michelle  2010-10-06        Boston                  5.0
# 4615   255183  Michelle  2010-10-06        Boston                  5.0
# 4634   255183  Michelle  2010-10-06        Boston                  5.0
# 4635   255183  Michelle  2010-10-06        Boston                  5.0
# 4699   255183  Michelle  2010-10-06        Boston                  5.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 136   256203   Shannon  2010-10-07       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1903   257237     Laura  2010-10-09       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6895   261895      John  2010-10-14           San                  2.0
# 6921   261895      John  2010-10-14           San                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4727   265036   Claudia  2010-10-18        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4969   271917    Sheryl  2010-10-26        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6710   271947      Bill  2010-10-26        Boston                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 871   273088     Gerry  2010-10-28       Seattle                  2.0
# 946   273088     Gerry  2010-10-28       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 7222   274270      Tony  2010-10-29        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 7261   274767    Bechir  2010-10-30        Boston                  1.0
#
#
#      host_id        host_name  host_since host_location  host_listings_count
# 170   276239  Jacob And Katie  2010-11-01       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2281   278781   Derrick  2010-11-04       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5649   280497     Sarah  2010-11-07        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4505   280539   Mariana  2010-11-07        Boston                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 443   282560      Rama  2010-11-09       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 
Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2002   394231     Sonny  2011-02-16       Seattle                  2.0
# 3279   394231     Sonny  2011-02-16       Seattle                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3788   398005    Trevor  2011-02-18       Seattle                  1.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 594   398234     Scott  2011-02-18       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 6337   405376     Randi  2011-02-22        Boston                  2.0
# 6375   405376     Randi  2011-02-22        Boston                  2.0
#
#
#      host_id host_name  host_since host_location  host_listings_count
# 667   406209  Kathleen  2011-02-23       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1087   406456  Brittany  2011-02-23       Seattle                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5248   409027   Esteban  2011-02-24        Buenos                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 1840   409899   Eleanor  2011-02-25       Seattle                  1.0
#
#
#       host_id   host_name  host_since host_location  host_listings_count
# 5513   416912  Christiane  2011-03-01        Boston                  2.0
# 5590   416912  Christiane  2011-03-01        Boston                  2.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2508   429330     Trudi  2011-03-08       Seattle                  1.0
#
#
#       host_id           host_name  host_since host_location  \
# 97     430709  Sea To Sky Rentals  2011-03-08       Seattle
# 231    430709  Sea To Sky Rentals  2011-03-08       Seattle
# 364    430709  Sea To Sky Rentals  2011-03-08       Seattle
# 731    430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1216   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1223   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1260   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1267   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1277   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1281   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1313   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1318   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1327   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1332   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1335   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1365   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1368   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1373   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1375   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1382   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1391   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1420   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1472   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1512   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1514   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1742   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 1855   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 2809   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3000   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3359   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3369   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3373   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3379   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3384   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3738   430709  Sea To Sky Rentals  2011-03-08       Seattle
# 3744   430709  Sea To Sky Rentals  2011-03-08       Seattle
#
#       host_listings_count
# 97                   36.0
# 231                  36.0
# 364                  36.0
# 731                  36.0
# 1216                 36.0
# 1223                 36.0
# 1260                 36.0
# 1267                 36.0
# 1277                 36.0
# 1281                 36.0
# 1313                 36.0
# 1318                 36.0
# 1327                 36.0
# 1332                 36.0
# 1335                 36.0
# 1365                 36.0
# 1368                 36.0
# 1373                 36.0
# 1375                 36.0
# 1382                 36.0
# 1391                 36.0
# 1420                 36.0
# 1472                 36.0
# 1512                 36.0
# 1514                 36.0
# 1742                 36.0
# 1855                 36.0
# 2809                 36.0
# 3000                 36.0
# 3359                 36.0
# 3369                 36.0
# 3373                 36.0
# 3379                 36.0
# 3384                 36.0
# 3738                 36.0
# 3744                 36.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 3834   431385   Cynthia  2011-03-09        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 4824   432317     Julie  2011-03-09        Boston                  1.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 5420   434539    Brahma  2011-03-10        Boston                  3.0
# 5438   434539    Brahma  2011-03-10        Boston                  3.0
# 5475   434539    Brahma  2011-03-10        Boston                  3.0
#
#
#       host_id host_name  host_since host_location  host_listings_count
# 2124   437055     Jyoti  2011-03-12       Seattle                  1.0
#
#
#       host_id       host_name  host_since host_location  host_listings_count
# 4149   449295  Dorothy & Seth  2011-03-18        Boston                  2.0
# ...
# 4668  81103542     Marie  2016-07-01        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4471  81152656    Malory  2016-07-01        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6410  81160490     Faruk  2016-07-01        Boston                  2.0
# 6447  81160490     Faruk  2016-07-01        Boston                  2.0
#
#
#        host_id         host_name  host_since host_location  \
# 5989  81301451  Azize And Vivian  2016-07-02        Boston
#
#       host_listings_count
# 5989                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 
US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6484  88543034    Robert  2016-08-07        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 7250  88908642     Kevin  2016-08-09            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6378  89089164     Ellen  2016-08-10        Boston                  1.0
#
#
#        host_id  host_name  host_since host_location  host_listings_count
# 5644  89153895  Elizabeth  2016-08-10            US                  1.0
#
#
#        host_id         host_name  host_since host_location  \
# 6539  89209244  Valerie And Joel  2016-08-10            US
#
#       host_listings_count
# 6539                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4093  89230454      Asad  2016-08-10            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4425  89613233    Krista  2016-08-13            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6282  89873768   Praveen  2016-08-14            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 7372  89884123     Craig  2016-08-14            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 7368  90052719      Pohl  2016-08-15            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5383  90216774   Natalia  2016-08-16        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4793  90491687      John  2016-08-17        Boston                  1.0
#
#
#        host_id      host_name  host_since host_location  host_listings_count
# 7389  90497470  Sofia And Kim  2016-08-17     Brookline                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6027  90512786     Ainur  2016-08-17      Gearhart                  3.0
# 6163  90512786     Ainur  2016-08-17      Gearhart                  3.0
# 6268  90512786     Ainur  2016-08-17      Gearhart                  3.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5533  90526463    Darren  2016-08-17            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6071  90540199    Ulrich  2016-08-17        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 7375  90615440   Maureen  2016-08-18        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6319  90839028     Jiayi  2016-08-19        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6030  91070657     Manan  2016-08-21            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 7108  91096414    Lauren  2016-08-21        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6583  91099010      Mary  2016-08-21            US                  3.0
# 6584  91099010      Mary  2016-08-21            US                  3.0
# 6592  91099010      Mary  2016-08-21            US                  3.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4288  91169115     Ellen  2016-08-21        Boston                  2.0
# 4293  91169115     Ellen  2016-08-21        Boston                  2.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4138  91197438   Vinayak  2016-08-21            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6464  91411121      Moon  2016-08-23        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6651  91521392    Joseph  2016-08-23            US                  2.0
# 6747  91521392    Joseph  2016-08-23            US                  2.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5330  91548283   Anthony  2016-08-23        Boston                  2.0
# 5355  91548283   Anthony  2016-08-23        Boston                  2.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6690  91831056     Yizuo  2016-08-25            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6488  91855319        公主  2016-08-25            US                  2.0
# 7392  91855319        公主  2016-08-25            US                  2.0
#
#
#        host_id host_name  host_since  host_location  host_listings_count
# 6339  91968083   Maureen  2016-08-26  Massachusetts                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6113  92196747      Neza  2016-08-27        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4357  92648590      Paul  2016-08-30            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 7379  92650841     Chloe  2016-08-30            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4839  92663980      Fadi  2016-08-30        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6619  92712021     Zulma  2016-08-30            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6952  92878185    Victor  2016-08-31            US                  2.0
# 6964  92878185    Victor  2016-08-31            US                  2.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5933  93031650       Kay  2016-09-01      Bluffton                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5720  93035834     Erika  2016-09-01            US                  2.0
# 5828  93035834     Erika  2016-09-01            US                  2.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5712  93051119      Mary  2016-09-01            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6436  93115614     Selim  2016-09-02            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 4766  93363670     Mason  2016-09-03            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5440  93364702      Aria  2016-09-03        Boston                  1.0
#
#
#        host_id  host_name  host_since host_location  host_listings_count
# 4389  93512984  Valentino  2016-09-04        Boston                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 3925  93635490     Isaac  2016-09-05            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6459  93674064  Benjamin  2016-09-05            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 5517  93820834     Maria  2016-09-06            US                  1.0
#
#
#        host_id host_name  host_since host_location  host_listings_count
# 6607  93854106    Pastor  2016-09-06            US                  1.0
