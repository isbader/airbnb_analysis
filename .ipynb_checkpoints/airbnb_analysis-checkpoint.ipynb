# %% [markdown]
# ## DSND Project1

# %% [markdown]
# #### DataSets Used:
#
# **For this project two datasets were used**
# - Seattle AirBNB Data
# - Boston AirBNB Data

# %% [markdown]
# #### Problem statment:-
# - What features have the highest corrilation with the price
# - Can we generlize that if a property is at a certin location it will effect the price

# %% [markdown]
# ***
# ***

# %%
#Imports
import pandas as pd 
import numpy as np 
import sklearn

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
#pd.set_option('display.max_rows', 20)

# %% [markdown]
# ## Data Understaning

# %% [markdown]
# #### Boston

# %%
#Reading the data
boston_listing = pd.read_csv('data/boston/listings.csv')

# %%
#understanding the data
boston_listing.columns , boston_listing.shape
# Out:
# (Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#         'space', 'description', 'experiences_offered', 'neighborhood_overview',
#         'notes', 'transit', 'access', 'interaction', 'house_rules',
#         'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#         'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#         'host_about', 'host_response_time', 'host_response_rate',
#         'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#         'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#         'host_total_listings_count', 'host_verifications',
#         'host_has_profile_pic', 'host_identity_verified', 'street',
#         'neighbourhood', 'neighbourhood_cleansed',
#         'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#         'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#         'is_location_exact', 'property_type', 'room_type', 'accommodates',
#         'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#         'price', 'weekly_price', 'monthly_price', 'security_deposit',
#         'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#         'maximum_nights', 'calendar_updated', 'has_availability',
#         'availability_30', 'availability_60', 'availability_90',
#         'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#         'first_review', 'last_review', 'review_scores_rating',
#         'review_scores_accuracy', 'review_scores_cleanliness',
#         'review_scores_checkin', 'review_scores_communication',
#         'review_scores_location', 'review_scores_value', 'requires_license',
#         'license', 'jurisdiction_names', 'instant_bookable',
#         'cancellation_policy', 'require_guest_profile_picture',
#         'require_guest_phone_verification', 'calculated_host_listings_count',
#         'reviews_per_month'],
#        dtype='object'),
#  (3585, 95))

# %%
boston_listing.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Most places you find in Boston are small howev...
# 4  Clean, attractive, private room, one block fro...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
# 2  Come stay with a friendly, middle-aged guy in ...                none
# 3  Come experience the comforts of home away from...                none
# 4  My comfy, clean and relaxing home is one block...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0  Roslindale is quiet, convenient and friendly. ...  ...                 NaN
# 1  The room is in Roslindale, a diverse and prima...  ...                 9.0
# 2  The LOCATION: Roslindale is a safe and diverse...  ...                10.0
# 3  Roslindale is a lovely little neighborhood loc...  ...                10.0
# 4  I love the proximity to downtown, the neighbor...  ...                10.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN                NaN                f
# 1                f     NaN                NaN                t
# 2                f     NaN                NaN                f
# 3                f     NaN                NaN                f
# 4                f     NaN                NaN                f
#
#   cancellation_policy require_guest_profile_picture  \
# 0            moderate                             f
# 1            moderate                             f
# 2            moderate                             t
# 3            moderate                             f
# 4            flexible                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 95 columns]

# %%
boston_listing.isnull().sum()
# Out:
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   756
# Length: 95, dtype: int64

# %%
# make a column to identify the city before merging
boston_listing['city'].fillna('boston',inplace=True)
boston_listing['city'].value_counts()
# Out:
# Boston                       3381
# Roxbury Crossing               24
# Somerville                     19
# Jamaica Plain                  18
# Brookline                      18
# Cambridge                      16
# Charlestown                    15
# Dorchester                     15
# Brighton                       15
# Allston                        12
# Roslindale                      6
# West Roxbury                    5
# ROXBURY CROSSING                4
# East Boston                     3
# Mattapan                        3
# boston                          3
# South Boston                    2
# Boston, Massachusetts, US       2
# Jamaica Plain, Boston           2
# ALLSTON                         2
# Hyde Park                       2
# Jamaica Plain                   2
# South End, Boston               1
# Boston                          1
# Mission Hill, Boston            1
# Watertown                       1
# 波士顿                             1
# Jamaica Plain (Boston)          1
# Roslindale, Boston              1
# east Boston                     1
# dorchester, boston              1
# Jamaica Plain, MA               1
# Brighton                        1
# Boston (Charlestown)            1
# Boston (Jamaica Plain)          1
# Milton                          1
# Newton                          1
# Jamaica plain                   1
# Name: city, dtype: int64

# %% [markdown]
# ### seattle

# %%
seattle_listing = pd.read_csv('data/seattle/listings.csv')

# %%
seattle_listing.columns , seattle_listing.shape
# Out:
# (Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#         'space', 'description', 'experiences_offered', 'neighborhood_overview',
#         'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#         'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#         'host_location', 'host_about', 'host_response_time',
#         'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#         'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#         'host_listings_count', 'host_total_listings_count',
#         'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#         'street', 'neighbourhood', 'neighbourhood_cleansed',
#         'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#         'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#         'is_location_exact', 'property_type', 'room_type', 'accommodates',
#         'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#         'price', 'weekly_price', 'monthly_price', 'security_deposit',
#         'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#         'maximum_nights', 'calendar_updated', 'has_availability',
#         'availability_30', 'availability_60', 'availability_90',
#         'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#         'first_review', 'last_review', 'review_scores_rating',
#         'review_scores_accuracy', 'review_scores_cleanliness',
#         'review_scores_checkin', 'review_scores_communication',
#         'review_scores_location', 'review_scores_value', 'requires_license',
#         'license', 'jurisdiction_names', 'instant_bookable',
#         'cancellation_policy', 'require_guest_profile_picture',
#         'require_guest_phone_verification', 'calculated_host_listings_count',
#         'reviews_per_month'],
#        dtype='object'),
#  (3818, 92))

# %%
seattle_listing.isnull().sum()
# Out:
# id                                    0
# listing_url                           0
# scrape_id                             0
# last_scraped                          0
# name                                  0
#                                    ...
# cancellation_policy                   0
# require_guest_profile_picture         0
# require_guest_phone_verification      0
# calculated_host_listings_count        0
# reviews_per_month                   627
# Length: 92, dtype: int64

# %%
# make a column to identify the city before merging
seattle_listing['city'].fillna('seattle',inplace=True)
seattle_listing['city'].value_counts()
# Out:
# Seattle                  3810
# Seattle                     2
# West Seattle                2
# Phinney Ridge Seattle       1
# 西雅图                         1
# seattle                     1
# Ballard, Seattle            1
# Name: city, dtype: int64

# %%
# visulizing the missing values before merging
def missing_heat_map(DataFrame):
        import numpy as np
        import pandas as pd
        import seaborn as sns
        import matplotlib.pyplot as plt
        sns.set_style('whitegrid')
        
        
    # plot the missing values
        fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize = (18, 6))
        sns.heatmap(DataFrame.isnull(), yticklabels=False, ax = ax, cbar=False, cmap='viridis')
        ax.set_title('dataset')
        plt.show()
        
    # Calculate the missing values to get a percentage 

        for i in DataFrame:
            print(i,': %',int((DataFrame[i].isnull().sum()/len(DataFrame[i]))*100),\
                  'With {} missing values'.format((DataFrame[i].isnull().sum())))

# %%
# Understand the missing values for seattle dataset
missing_heat_map(seattle_listing)
# Out:
# id : % 0 With 0 missing values
# listing_url : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# summary : % 4 With 177 missing values
# space : % 14 With 569 missing values
# description : % 0 With 0 missing values
# experiences_offered : % 0 With 0 missing values
# neighborhood_overview : % 27 With 1032 missing values
# notes : % 42 With 1606 missing values
# transit : % 24 With 934 missing values
# thumbnail_url : % 8 With 320 missing values
# medium_url : % 8 With 320 missing values
# picture_url : % 0 With 0 missing values
# xl_picture_url : % 8 With 320 missing values
# host_id : % 0 With 0 missing values
# host_url : % 0 With 0 missing values
# host_name : % 0 With 2 missing values
# host_since : % 0 With 2 missing values
# host_location : % 0 With 8 missing values
# host_about : % 22 With 859 missing values
# host_response_time : % 13 With 523 missing values
# host_response_rate : % 13 With 523 missing values
# host_acceptance_rate : % 20 With 773 missing values
# host_is_superhost : % 0 With 2 missing values
# host_thumbnail_url : % 0 With 2 missing values
# host_picture_url : % 0 With 2 missing values
# host_neighbourhood : % 7 With 300 missing values
# host_listings_count : % 0 With 2 missing values
# host_total_listings_count : % 0 With 2 missing values
# host_verifications : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 2 missing values
# host_identity_verified : % 0 With 2 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 10 With 416 missing values
# neighbourhood_cleansed : % 0 With 0 missing values
# neighbourhood_group_cleansed : % 0 With 0 missing values
# city : % 0 With 0 missing values
# state : % 0 With 0 missing values
# zipcode : % 0 With 7 missing values
# market : % 0 With 0 missing values
# smart_location : % 0 With 0 missing values
# country_code : % 0 With 0 missing values
# country : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 1 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 16 missing values
# bedrooms : % 0 With 6 missing values
# beds : % 0 With 1 missing values
# bed_type : % 0 With 0 missing values
# amenities : % 0 With 0 missing values
# square_feet : % 97 With 3721 missing values
# price : % 0 With 0 missing values
# weekly_price : % 47 With 1809 missing values
# monthly_price : % 60 With 2301 missing values
# security_deposit : % 51 With 1952 missing values
# cleaning_fee : % 26 With 1030 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 0 With 0 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 16 With 627 missing values
# last_review : % 16 With 627 missing values
# review_scores_rating : % 16 With 647 missing values
# review_scores_accuracy : % 17 With 658 missing values
# review_scores_cleanliness : % 17 With 653 missing values
# review_scores_checkin : % 17 With 658 missing values
# review_scores_communication : % 17 With 651 missing values
# review_scores_location : % 17 With 655 missing values
# review_scores_value : % 17 With 656 missing values
# requires_license : % 0 With 0 missing values
# license : % 100 With 3818 missing values
# jurisdiction_names : % 0 With 0 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 16 With 627 missing values

# %%
# Understand the missing values for the boston dataset
missing_heat_map(boston_listing)
# Out:
# id : % 0 With 0 missing values
# listing_url : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# summary : % 3 With 143 missing values
# space : % 29 With 1057 missing values
# description : % 0 With 0 missing values
# experiences_offered : % 0 With 0 missing values
# neighborhood_overview : % 39 With 1415 missing values
# notes : % 55 With 1975 missing values
# transit : % 35 With 1290 missing values
# access : % 41 With 1489 missing values
# interaction : % 43 With 1554 missing values
# house_rules : % 33 With 1192 missing values
# thumbnail_url : % 16 With 599 missing values
# medium_url : % 16 With 599 missing values
# picture_url : % 0 With 0 missing values
# xl_picture_url : % 16 With 599 missing values
# host_id : % 0 With 0 missing values
# host_url : % 0 With 0 missing values
# host_name : % 0 With 0 missing values
# host_since : % 0 With 0 missing values
# host_location : % 0 With 11 missing values
# host_about : % 36 With 1309 missing values
# host_response_time : % 13 With 471 missing values
# host_response_rate : % 13 With 471 missing values
# host_acceptance_rate : % 13 With 471 missing values
# host_is_superhost : % 0 With 0 missing values
# host_thumbnail_url : % 0 With 0 missing values
# host_picture_url : % 0 With 0 missing values
# host_neighbourhood : % 9 With 339 missing values
# host_listings_count : % 0 With 0 missing values
# host_total_listings_count : % 0 With 0 missing values
# host_verifications : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 0 missing values
# host_identity_verified : % 0 With 0 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 15 With 543 missing values
# neighbourhood_cleansed : % 0 With 0 missing values
# neighbourhood_group_cleansed : % 100 With 3585 missing values
# city : % 0 With 0 missing values
# state : % 0 With 0 missing values
# zipcode : % 1 With 38 missing values
# market : % 0 With 14 missing values
# smart_location : % 0 With 0 missing values
# country_code : % 0 With 0 missing values
# country : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 3 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 14 missing values
# bedrooms : % 0 With 10 missing values
# beds : % 0 With 9 missing values
# bed_type : % 0 With 0 missing values
# amenities : % 0 With 0 missing values
# square_feet : % 98 With 3529 missing values
# price : % 0 With 0 missing values
# weekly_price : % 75 With 2693 missing values
# monthly_price : % 75 With 2697 missing values
# security_deposit : % 62 With 2243 missing values
# cleaning_fee : % 30 With 1107 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 100 With 3585 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 21 With 756 missing values
# last_review : % 21 With 756 missing values
# review_scores_rating : % 22 With 813 missing values
# review_scores_accuracy : % 22 With 823 missing values
# review_scores_cleanliness : % 22 With 818 missing values
# review_scores_checkin : % 22 With 820 missing values
# review_scores_communication : % 22 With 818 missing values
# review_scores_location : % 22 With 822 missing values
# review_scores_value : % 22 With 821 missing values
# requires_license : % 0 With 0 missing values
# license : % 100 With 3585 missing values
# jurisdiction_names : % 100 With 3585 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 21 With 756 missing values

# %%
# get the column list that is in both datasets
column_list = set(seattle_listing.columns).intersection(boston_listing.columns)
column_list = list(column_list)

# %%
# check that the columns match before merging the two datasets 

# get the unique columns in the seattle dataset
seattle_unique = [x for x in seattle_listing if x not in column_list]
print(seattle_unique)

# get the unique columns in the boston_ls dataset
boston_unique = [x for x in boston_listing if x not in column_list]
print(boston_unique)
# Out:
# []
# ['access', 'interaction', 'house_rules']

# %% [markdown]
# **This means that both datasets don't have column naming issues**

# %%
#Checking the unique columns in the boston dataset
boston_listing[['access','interaction','house_rules']].isnull().sum()
# Out:
# access         1489
# interaction    1554
# house_rules    1192
# dtype: int64

# %%
# merge both datasets for an esier cleaning process
df = pd.concat([seattle_listing,boston_listing],ignore_index=True)

# %%
df.shape
# Out:
# (7403, 95)

# %%
missing_heat_map(df)
# Out:
# id : % 0 With 0 missing values
# listing_url : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# summary : % 4 With 320 missing values
# space : % 21 With 1626 missing values
# description : % 0 With 0 missing values
# experiences_offered : % 0 With 0 missing values
# neighborhood_overview : % 33 With 2447 missing values
# notes : % 48 With 3581 missing values
# transit : % 30 With 2224 missing values
# thumbnail_url : % 12 With 919 missing values
# medium_url : % 12 With 919 missing values
# picture_url : % 0 With 0 missing values
# xl_picture_url : % 12 With 919 missing values
# host_id : % 0 With 0 missing values
# host_url : % 0 With 0 missing values
# host_name : % 0 With 2 missing values
# host_since : % 0 With 2 missing values
# host_location : % 0 With 19 missing values
# host_about : % 29 With 2168 missing values
# host_response_time : % 13 With 994 missing values
# host_response_rate : % 13 With 994 missing values
# host_acceptance_rate : % 16 With 1244 missing values
# host_is_superhost : % 0 With 2 missing values
# host_thumbnail_url : % 0 With 2 missing values
# host_picture_url : % 0 With 2 missing values
# host_neighbourhood : % 8 With 639 missing values
# host_listings_count : % 0 With 2 missing values
# host_total_listings_count : % 0 With 2 missing values
# host_verifications : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 2 missing values
# host_identity_verified : % 0 With 2 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 12 With 959 missing values
# neighbourhood_cleansed : % 0 With 0 missing values
# neighbourhood_group_cleansed : % 48 With 3585 missing values
# city : % 0 With 0 missing values
# state : % 0 With 0 missing values
# zipcode : % 0 With 45 missing values
# market : % 0 With 14 missing values
# smart_location : % 0 With 0 missing values
# country_code : % 0 With 0 missing values
# country : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 4 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 30 missing values
# bedrooms : % 0 With 16 missing values
# beds : % 0 With 10 missing values
# bed_type : % 0 With 0 missing values
# amenities : % 0 With 0 missing values
# square_feet : % 97 With 7250 missing values
# price : % 0 With 0 missing values
# weekly_price : % 60 With 4502 missing values
# monthly_price : % 67 With 4998 missing values
# security_deposit : % 56 With 4195 missing values
# cleaning_fee : % 28 With 2137 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 48 With 3585 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 18 With 1383 missing values
# last_review : % 18 With 1383 missing values
# review_scores_rating : % 19 With 1460 missing values
# review_scores_accuracy : % 20 With 1481 missing values
# review_scores_cleanliness : % 19 With 1471 missing values
# review_scores_checkin : % 19 With 1478 missing values
# review_scores_communication : % 19 With 1469 missing values
# review_scores_location : % 19 With 1477 missing values
# review_scores_value : % 19 With 1477 missing values
# requires_license : % 0 With 0 missing values
# license : % 100 With 7403 missing values
# jurisdiction_names : % 48 With 3585 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 18 With 1383 missing values
# access : % 71 With 5307 missing values
# interaction : % 72 With 5372 missing values
# house_rules : % 67 With 5010 missing values

# %%
df.dtypes
# Out:
# id                                  int64
# listing_url                        object
# scrape_id                           int64
# last_scraped                       object
# name                               object
#                                    ...
# calculated_host_listings_count      int64
# reviews_per_month                 float64
# access                             object
# interaction                        object
# house_rules                        object
# Length: 95, dtype: object

# %%
df.to_csv('full_data.csv')

# %% [markdown]
# ***
# ***

# %% [markdown]
# ## Data prepreation

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7403 entries, 0 to 7402
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                7403 non-null   int64
#  1   listing_url                       7403 non-null   object
#  2   scrape_id                         7403 non-null   int64
#  3   last_scraped                      7403 non-null   object
#  4   name                              7403 non-null   object
#  5   summary                           7083 non-null   object
#  6   space                             5777 non-null   object
#  7   description                       7403 non-null   object
#  8   experiences_offered               7403 non-null   object
#  9   neighborhood_overview             4956 non-null   object
#  10  notes                             3822 non-null   object
#  11  transit                           5179 non-null   object
#  12  thumbnail_url                     6484 non-null   object
#  13  medium_url                        6484 non-null   object
#  14  picture_url                       7403 non-null   object
#  15  xl_picture_url                    6484 non-null   object
#  16  host_id                           7403 non-null   int64
#  17  host_url                          7403 non-null   object
#  18  host_name                         7401 non-null   object
#  19  host_since                        7401 non-null   object
#  20  host_location                     7384 non-null   object
#  21  host_about                        5235 non-null   object
#  22  host_response_time                6409 non-null   object
#  23  host_response_rate                6409 non-null   object
#  24  host_acceptance_rate              6159 non-null   object
#  25  host_is_superhost                 7401 non-null   object
#  26  host_thumbnail_url                7401 non-null   object
#  27  host_picture_url                  7401 non-null   object
#  28  host_neighbourhood                6764 non-null   object
#  29  host_listings_count               7401 non-null   float64
#  30  host_total_listings_count         7401 non-null   float64
#  31  host_verifications                7403 non-null   object
#  32  host_has_profile_pic              7401 non-null   object
#  33  host_identity_verified            7401 non-null   object
#  34  street                            7403 non-null   object
#  35  neighbourhood                     6444 non-null   object
#  36  neighbourhood_cleansed            7403 non-null   object
#  37  neighbourhood_group_cleansed      3818 non-null   object
#  38  city                              7403 non-null   object
#  39  state                             7403 non-null   object
#  40  zipcode                           7358 non-null   object
#  41  market                            7389 non-null   object
#  42  smart_location                    7403 non-null   object
#  43  country_code                      7403 non-null   object
#  44  country                           7403 non-null   object
#  45  latitude                          7403 non-null   float64
#  46  longitude                         7403 non-null   float64
#  47  is_location_exact                 7403 non-null   object
#  48  property_type                     7399 non-null   object
#  49  room_type                         7403 non-null   object
#  50  accommodates                      7403 non-null   int64
#  51  bathrooms                         7373 non-null   float64
#  52  bedrooms                          7387 non-null   float64
#  53  beds                              7393 non-null   float64
#  54  bed_type                          7403 non-null   object
#  55  amenities                         7403 non-null   object
#  56  square_feet                       153 non-null    float64
#  57  price                             7403 non-null   object
#  58  weekly_price                      2901 non-null   object
#  59  monthly_price                     2405 non-null   object
#  60  security_deposit                  3208 non-null   object
#  61  cleaning_fee                      5266 non-null   object
#  62  guests_included                   7403 non-null   int64
#  63  extra_people                      7403 non-null   object
#  64  minimum_nights                    7403 non-null   int64
#  65  maximum_nights                    7403 non-null   int64
#  66  calendar_updated                  7403 non-null   object
#  67  has_availability                  3818 non-null   object
#  68  availability_30                   7403 non-null   int64
#  69  availability_60                   7403 non-null   int64
#  70  availability_90                   7403 non-null   int64
#  71  availability_365                  7403 non-null   int64
#  72  calendar_last_scraped             7403 non-null   object
#  73  number_of_reviews                 7403 non-null   int64
#  74  first_review                      6020 non-null   object
#  75  last_review                       6020 non-null   object
#  76  review_scores_rating              5943 non-null   float64
#  77  review_scores_accuracy            5922 non-null   float64
#  78  review_scores_cleanliness         5932 non-null   float64
#  79  review_scores_checkin             5925 non-null   float64
#  80  review_scores_communication       5934 non-null   float64
#  81  review_scores_location            5926 non-null   float64
#  82  review_scores_value               5926 non-null   float64
#  83  requires_license                  7403 non-null   object
#  84  license                           0 non-null      float64
#  85  jurisdiction_names                3818 non-null   object
#  86  instant_bookable                  7403 non-null   object
#  87  cancellation_policy               7403 non-null   object
#  88  require_guest_profile_picture     7403 non-null   object
#  89  require_guest_phone_verification  7403 non-null   object
#  90  calculated_host_listings_count    7403 non-null   int64
#  91  reviews_per_month                 6020 non-null   float64
#  92  access                            2096 non-null   object
#  93  interaction                       2031 non-null   object
#  94  house_rules                       2393 non-null   object
# dtypes: float64(17), int64(13), object(65)
# memory usage: 5.4+ MB

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**listing_url**|`object`|Delete since URL not needed|
# |**picture_url**|`object`|Delete since URL not needed|
# |**xl_picture_url**|`object`|Delete since URL not needed|
# |**host_url**|`object`|Delete since URL not needed|
# |**host_thumbnail_url**|`object`|Delete since URL not needed|
# |**medium_url**|`object`|Delete since URL not needed|
# |**thumbnail_url**|`object`|Delete since URL not needed|
# |**host_picture_url**|`object`|Delete since URL not needed|
# |**square_feet**|`float64`|remove since %97 percent of data is missing|
# |**license**|`NaN`|remove since %100 percent of data is missing|

# %%
# removing some unnessary columns(rest will be removed later)
del df['listing_url']
del df['picture_url']
del df['xl_picture_url']
del df['host_url']
del df['host_thumbnail_url']
del df['medium_url']
del df['thumbnail_url']
del df['host_picture_url']
del df['license']
del df['square_feet']

# %%
df.isnull().sum()
# Out:
# id                                   0
# scrape_id                            0
# last_scraped                         0
# name                                 0
# summary                            320
#                                   ...
# calculated_host_listings_count       0
# reviews_per_month                 1383
# access                            5307
# interaction                       5372
# house_rules                       5010
# Length: 85, dtype: int64

# %% [markdown]
# **Now I will try to go through each column and evaluate it**

# %% [markdown]
# **Since I will not choose an NLP approch.I will extract the number of words each of these strings and replace the column which might serve as a feature worth exploring**
#
# |Feature|Type|Action|
# |---|---|---|
# |**summary**|`object`|Get the word count insted|
# |**space**|`object`|Get the word count insted|
# |**description**|`object`|Get the word count insted|
# |**neighborhood_overview**|`object`|Get the word count insted|
# |**transit**|`object`|Get the word count insted|
# |**host_about**|`object`|Get the word count insted|
# |**notes**|`object`|Get the word count insted|

# %%
def get_wordcount(column,df=df):
    return df[str(column)].apply(lambda x : len(x.split(' ')) if type(x) == str else 0)

# %%
# calculate the wordcount of the columns above and apply it to new columns
df['summary_wc'] = get_wordcount('summary')
df['space_wc'] = get_wordcount('space')
df['description_wc'] = get_wordcount('description')
df['neighborhood_overview_wc'] = get_wordcount('neighborhood_overview')
df['transit_wc'] = get_wordcount('transit')
df['host_about_wc'] = get_wordcount('host_about')
df['notes_wc'] = get_wordcount('notes')

# %%
# delete the columns 
del df['summary']
del df['space']
del df['description']
del df['neighborhood_overview']
del df['transit']
del df['host_about']
del df['notes']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**experiences_offered**|`object`|delete since all values are none|

# %%
# check column 
df['experiences_offered'].head()
# Out:
# 0    none
# 1    none
# 2    none
# 3    none
# 4    none
# Name: experiences_offered, dtype: object

# %%
#check values
df['experiences_offered'].value_counts()
# Out:
# none    7403
# Name: experiences_offered, dtype: int64

# %%
#delete column
del df['experiences_offered']

# %% [markdown]
# #### Location features:-

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**host_location**|`object`|clean|
# |**smart_location**|`object`|clean|
# |**city**|`object`|delete to avoid redundency|
# |**zipcode**|`object`|clean|
# |**state**|`object`|delete to avoid redundency|
# |**country**|`object`|delete to avoid redundency|
# |**street**|`object`|clean|
# |**neighbourhood**|`object`|clean|
# |**country_code**|`object`|delete to avoid redundency|
# |**latitude**|`Float`|clean|
# |**longitude**|`Float`|clean|
# |**is_location_exact**|`object`|clean|

# %%
df[['host_location','smart_location','city','state','country','country_code','is_location_exact']]
# Out:
#                                  host_location  smart_location        city  \
# 0           Seattle, Washington, United States     Seattle, WA     Seattle
# 1           Seattle, Washington, United States     Seattle, WA     Seattle
# 2           Seattle, Washington, United States     Seattle, WA     Seattle
# 3           Seattle, Washington, United States     Seattle, WA     Seattle
# 4           Seattle, Washington, United States     Seattle, WA     Seattle
# ...                                        ...             ...         ...
# 7398  Somerville, Massachusetts, United States  Somerville, MA  Somerville
# 7399                                        US   Brookline, MA   Brookline
# 7400         New York, New York, United States   Cambridge, MA   Cambridge
# 7401  Somerville, Massachusetts, United States  Somerville, MA  Somerville
# 7402  Somerville, Massachusetts, United States  Somerville, MA  Somerville
#
#      state        country country_code is_location_exact
# 0       WA  United States           US                 t
# 1       WA  United States           US                 t
# 2       WA  United States           US                 t
# 3       WA  United States           US                 t
# 4       WA  United States           US                 t
# ...    ...            ...          ...               ...
# 7398    MA  United States           US                 t
# 7399    MA  United States           US                 f
# 7400    MA  United States           US                 f
# 7401    MA  United States           US                 t
# 7402    MA  United States           US                 t
#
# [7403 rows x 7 columns]

# %% [markdown]
# **split the locations to get the city only which will reduce the value count and help with matching the host location to the property location**

# %%
#split the host_location to get only the city
df['host_location'] = df['host_location'].apply(lambda x : x.split(',')[0].split(' ')[0] if type(x) == str else 'unknown')
#split the property location to get only the city
df['smart_location'] = df['smart_location'].apply(lambda x : x.split(',')[0].split(' ')[0] if type(x) == str else 'unknown')

# %% [markdown]
# **check weather the host lives in the same city of the property or not**

# %%
#compare if the columns are equal put 1 else 0
df['host_match'] = np.where(df['host_location'] == df['smart_location'], 1, 0)

# %%
df['host_match'].value_counts()
# Out:
# 1    5598
# 0    1805
# Name: host_match, dtype: int64

# %%
# change the varibles to boolean of 0 and 1
df['is_location_exact'] = df['is_location_exact'].apply(lambda x : 1 if x == 't' else 0)
df['is_location_exact'].value_counts()
# Out:
# 1    6492
# 0     911
# Name: is_location_exact, dtype: int64

# %%
df[['zipcode','street','neighbourhood','latitude','longitude']].iloc[300:320]
# Out:
#     zipcode                                             street neighbourhood  \
# 300   98105  5th Avenue Northeast, Seattle, WA 98105, Unite...   Wallingford
# 301   98103  North 40th Street, Seattle, WA 98103, United S...   Wallingford
# 302   98103  North 43rd Street, Seattle, WA 98103, United S...   Wallingford
# 303   98103  Woodlawn Avenue North, Seattle, WA 98103, Unit...   Wallingford
# 304   98103  Interlake Avenue North, Seattle, WA 98103, Uni...   Wallingford
# 305   98103        N 40th St, Seattle, WA 98103, United States   Wallingford
# 306   98103    N 44th Street, Seattle, WA 98103, United States           NaN
# 307   98103  North 44th Street, Seattle, WA 98103, United S...   Wallingford
# 308   98103  East Green Lake Way N, Seattle, WA 98103, Unit...           NaN
# 309   98103        N 50th St, Seattle, WA 98103, United States   Wallingford
# 310   98103  Woodlawn Avenue North, Seattle, WA 98103, Unit...   Wallingford
# 311   98105  Thackeray Place Northeast, Seattle, WA 98105, ...   Wallingford
# 312   98103  North 45th Street, Seattle, WA 98103, United S...   Wallingford
# 313   98103  East Green Lake Way North, Seattle, WA 98103, ...   Wallingford
# 314   98105  2nd Avenue Northeast, Seattle, WA 98105, Unite...   Wallingford
# 315   98103  Corliss Avenue North, Seattle, WA 98103, Unite...   Wallingford
# 316   98103  Burke Avenue North, Seattle, WA 98103, United ...           NaN
# 317   98103     Kenwood Pl N, Seattle, WA 98103, United States   Wallingford
# 318   98103  North 48th Street, Seattle, WA 98103, United S...   Wallingford
# 319   98103  N Northlake Way, Seattle, WA 98103, United States           NaN
#
#       latitude   longitude
# 300  47.665856 -122.322691
# 301  47.656355 -122.338104
# 302  47.660147 -122.341530
# 303  47.666920 -122.338794
# 304  47.651586 -122.339903
# 305  47.655955 -122.332155
# 306  47.659912 -122.337686
# 307  47.661032 -122.335164
# 308  47.668363 -122.338887
# 309  47.663695 -122.336225
# 310  47.656119 -122.339032
# 311  47.661283 -122.326836
# 312  47.661073 -122.333498
# 313  47.669802 -122.338540
# 314  47.655897 -122.326535
# 315  47.650858 -122.331338
# 316  47.661503 -122.334257
# 317  47.669228 -122.335174
# 318  47.664147 -122.334250
# 319  47.648572 -122.340759

# %%
#fix the zip_code
#split the zipcode by dash
df['zipcode'] = df['zipcode'].apply(lambda x : x.split('-')[0] if type(x) == str else 'missing')
#split the zipcode by space
df['zipcode'] = df['zipcode'].apply(lambda x : x.split(' ')[0] if type(x) == str else 'missing')
df['zipcode'].value_counts().head(10)
# Out:
# 98122    420
# 98103    394
# 02116    388
# 98102    339
# 02130    331
# 02118    247
# 02215    236
# 02134    233
# 02114    231
# 98105    225
# Name: zipcode, dtype: int64

# %%
#Fill the missing values in neighbourhood column using the mode of the zipcode
grouped_loc = df[['zipcode','neighbourhood']].groupby('zipcode')
zipcode_hood = []
#loop over the grouped items
for key, item in grouped_loc:
    zipcode_hood.append(grouped_loc.get_group(key))# append result to list 

zipcode_list = []
neighbourhood_list = []

for i in range(0,70): #loop over the list using the index
    zipcode_list.append(zipcode_hood[i].mode()['zipcode'][0])
    neighbourhood_list.append(zipcode_hood[i].mode()['neighbourhood'][0])

#create a dataframe to include the zipcode and the the mode of each zipcode mode
df_ziphood = pd.DataFrame({'zipcode':zipcode_list,'neighbourhood':neighbourhood_list})
df_ziphood.head(15)
# Out:
#    zipcode      neighbourhood
# 0    02108        Beacon Hill
# 1    02109          North End
# 2    02110  Downtown Crossing
# 3    02111          Chinatown
# 4    02113          North End
# 5    02114        Beacon Hill
# 6    02115           Back Bay
# 7    02116           Back Bay
# 8    02118          South End
# 9    02119            Roxbury
# 10   02120       Mission Hill
# 11   02121            Roxbury
# 12   02122         Dorchester
# 13   02124         Dorchester
# 14   02125         Dorchester

# %% [markdown]
# **fill the missing values in neighbourhood from the dataframe above**

# %%
#delete unnassary columns
del df['city']
del df['state']
del df['country']
del df['country_code']

# %%
df.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'host_id', 'host_name',
#        'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'zipcode', 'market', 'smart_location',
#        'latitude', 'longitude', 'is_location_exact', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'bed_type', 'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'calendar_updated',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'calendar_last_scraped',
#        'number_of_reviews', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'jurisdiction_names',
#        'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month', 'access',
#        'interaction', 'house_rules', 'summary_wc', 'space_wc',
#        'description_wc', 'neighborhood_overview_wc', 'transit_wc',
#        'host_about_wc', 'notes_wc', 'host_match'],
#       dtype='object')

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**neighbourhood**|`object`|clean|
# |**neighbourhood_group_cleansed**|`object`|delete to avoid redundency|
# |**neighbourhood_cleansed**|`object`|delete to avoid redundency|

# %%
#fill the neighbourhood missing values from neighbourhood_cleansed
df[['neighbourhood','neighbourhood_group_cleansed','neighbourhood_cleansed']]
df['neighbourhood'].fillna(df['neighbourhood_cleansed'],inplace=True)

# %%
#delete unnassary columns
del df['neighbourhood_group_cleansed']
del df['neighbourhood_cleansed']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**host_name**|`object`|replace null with none|
# |**host_since**|`date_time`|replace null with median|
# |**host_response_time**|`object`|replace null with none|
# |**host_response_rate**|`object`|replace from median|
# |**host_acceptance_rate**|`object`|replace from median|
# |**host_is_superhost**|`object`|clean|
# |**host_neighbourhood**|`object`|delete to avoid redundency|

# %%
df['host_id'].isnull().sum()
# Out:
# 0

# %%
df[['host_id','host_name','host_since','host_response_time','host_response_rate','host_acceptance_rate']].isnull().sum().sum()
# Out:
# 3236

# %%
#group the host info to fill null values
grouped_host = df[['host_id','host_name','host_since','host_response_time','host_response_rate','host_acceptance_rate']].groupby('host_id')
host_info = []
for key, item in grouped_host:
    host_info.append(grouped_host.get_group(key))
    
#check the null values and validate using hosts other posts 
for i in host_info:
    print(i)
# Out:
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 2184     4193   Jessica  2008-11-10  within a few hours                88%
# 2190     4193   Jessica  2008-11-10  within a few hours                88%
# 2192     4193   Jessica  2008-11-10  within a few hours                88%
# 2194     4193   Jessica  2008-11-10  within a few hours                88%
#
#      host_acceptance_rate
# 2184                 100%
# 2190                 100%
# 2192                 100%
# 2194                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 7125     4240  Giuseppe  2008-11-11  within a few hours                90%
# 7341     4240  Giuseppe  2008-11-11  within a few hours                90%
#
#      host_acceptance_rate
# 7125                  78%
# 7341                  78%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5362     4804     Frank  2008-12-03       within a day                94%
#
#      host_acceptance_rate
# 5362                  69%
#       host_id      host_name  host_since host_response_time  \
# 1413     6207  Cory & Amanda  2009-01-08     within an hour
#
#      host_response_rate host_acceptance_rate
# 1413               100%                 100%
#       host_id                     host_name  host_since  host_response_time  \
# 2978     8021                         Becky  2009-02-16  within a few hours
# 3020     8021                         Becky  2009-02-16  within a few hours
# 3949     8021  L&B (Len & Becky Or Blenky*)  2009-02-16      within an hour
#
#      host_response_rate host_acceptance_rate
# 2978                75%                 100%
# 3020                75%                 100%
# 3949                94%                  95%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4658     8061     Heidi  2009-02-17  within a few hours               100%
#
#      host_acceptance_rate
# 4658                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4598     8229     Terry  2009-02-19       within a day               100%
# 4607     8229     Terry  2009-02-19       within a day               100%
# 4609     8229     Terry  2009-02-19       within a day               100%
# 4673     8229     Terry  2009-02-19       within a day               100%
# 4683     8229     Terry  2009-02-19       within a day               100%
# 4726     8229     Terry  2009-02-19       within a day               100%
#
#      host_acceptance_rate
# 4598                  90%
# 4607                  90%
# 4609                  90%
# 4673                  90%
# 4683                  90%
# 4726                  90%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2166     8993     Maddy  2009-03-03     within an hour               100%
#
#      host_acceptance_rate
# 2166                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 2242    11775    Andrew  2009-03-30  within a few hours               100%
#
#      host_acceptance_rate
# 2242                 100%
#      host_id host_name  host_since  host_response_time host_response_rate  \
# 377    14942     Joyce  2009-04-26  within a few hours                90%
# 420    14942     Joyce  2009-04-26  within a few hours                90%
# 430    14942     Joyce  2009-04-26  within a few hours                90%
#
#     host_acceptance_rate
# 377                 100%
# 420                 100%
# 430                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3820    16701      Phil  2009-05-11  within a few hours               100%
#
#      host_acceptance_rate
# 3820                  88%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2757    19425   Shireen  2009-05-30                NaN                NaN
#
#      host_acceptance_rate
# 2757                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1998    20731       Tik  2009-06-09     within an hour               100%
# 3338    20731       Tik  2009-06-09     within an hour               100%
#
#      host_acceptance_rate
# 1998                 100%
# 3338                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4217    25188  Seamless  2009-07-10  within a few hours                89%
# 4218    25188  Seamless  2009-07-10  within a few hours                89%
# 4238    25188  Seamless  2009-07-10  within a few hours                89%
# 4240    25188  Seamless  2009-07-10  within a few hours                89%
# 4330    25188  Seamless  2009-07-10  within a few hours                89%
# ...       ...       ...         ...                 ...                ...
# 6244    25188  Seamless  2009-07-10  within a few hours                89%
# 6245    25188  Seamless  2009-07-10  within a few hours                89%
# 6290    25188  Seamless  2009-07-10  within a few hours                89%
# 6291    25188  Seamless  2009-07-10  within a few hours                89%
# 6878    25188  Seamless  2009-07-10  within a few hours                89%
#
#      host_acceptance_rate
# 4217                  45%
# 4218                  45%
# 4238                  45%
# 4240                  45%
# 4330                  45%
# ...                   ...
# 6244                  45%
# 6245                  45%
# 6290                  45%
# 6291                  45%
# 6878                  45%
#
# [79 rows x 6 columns]
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4264    26988      Anne  2009-07-22  within a few hours               100%
# 5647    26988      Anne  2009-07-22  within a few hours               100%
# 5702    26988      Anne  2009-07-22  within a few hours               100%
# 5745    26988      Anne  2009-07-22  within a few hours               100%
# 5764    26988      Anne  2009-07-22  within a few hours               100%
# 5880    26988      Anne  2009-07-22  within a few hours               100%
# 5896    26988      Anne  2009-07-22  within a few hours               100%
# 5927    26988      Anne  2009-07-22  within a few hours               100%
# 5948    26988      Anne  2009-07-22  within a few hours               100%
# 5963    26988      Anne  2009-07-22  within a few hours               100%
#
#      host_acceptance_rate
# 4264                  93%
# 5647                  93%
# 5702                  93%
# 5745                  93%
# 5764                  93%
# 5880                  93%
# 5896                  93%
# 5927                  93%
# 5948                  93%
# 5963                  93%
#       host_id  host_name  host_since  host_response_time host_response_rate  \
# 1956    30559  Angielena  2009-08-09  within a few hours               100%
# 3479    30559  Angielena  2009-08-09  within a few hours               100%
# 3480    30559  Angielena  2009-08-09  within a few hours               100%
# 3483    30559  Angielena  2009-08-09  within a few hours               100%
# 3486    30559  Angielena  2009-08-09  within a few hours               100%
#
#      host_acceptance_rate
# 1956                 100%
# 3479                 100%
# 3480                 100%
# 3483                 100%
# 3486                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 2811    30604      Ekko  2009-08-09  within a few hours               100%
#
#      host_acceptance_rate
# 2811                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1592    30832     Siena  2009-08-10     within an hour               100%
# 1616    30832     Siena  2009-08-10     within an hour               100%
#
#      host_acceptance_rate
# 1592                 100%
# 1616                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1848    31481    Cassie  2009-08-13     within an hour               100%
# 1851    31481    Cassie  2009-08-13     within an hour               100%
#
#      host_acceptance_rate
# 1848                 100%
# 1851                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2645    31509     David  2009-08-13     within an hour               100%
# 2754    31509     David  2009-08-13     within an hour               100%
# 2849    31509     David  2009-08-13     within an hour               100%
# 2867    31509     David  2009-08-13     within an hour               100%
#
#      host_acceptance_rate
# 2645                 100%
# 2754                 100%
# 2849                 100%
# 2867                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1772    33360     Laura  2009-08-23     within an hour               100%
# 1853    33360     Laura  2009-08-23     within an hour               100%
# 1859    33360     Laura  2009-08-23     within an hour               100%
# 2379    33360     Laura  2009-08-23     within an hour               100%
# 3478    33360     Laura  2009-08-23     within an hour               100%
#
#      host_acceptance_rate
# 1772                 100%
# 1853                 100%
# 1859                 100%
# 2379                 100%
# 3478                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 468    34943       Kim  2009-08-30                NaN                NaN
#
#     host_acceptance_rate
# 468                  NaN
#       host_id    host_name  host_since host_response_time host_response_rate  \
# 2408    35749  Jess & Joey  2009-09-02       within a day               100%
# 2425    35749  Jess & Joey  2009-09-02       within a day               100%
# 2432    35749  Jess & Joey  2009-09-02       within a day               100%
# 2437    35749  Jess & Joey  2009-09-02       within a day               100%
# 3118    35749  Jess & Joey  2009-09-02       within a day               100%
#
#      host_acceptance_rate
# 2408                 100%
# 2425                 100%
# 2432                 100%
# 2437                 100%
# 3118                 100%
#       host_id           host_name  host_since host_response_time  \
# 7206    38440  The Farrington Inn  2009-09-14       within a day
# 7207    38440  The Farrington Inn  2009-09-14       within a day
# 7209    38440  The Farrington Inn  2009-09-14       within a day
# 7211    38440  The Farrington Inn  2009-09-14       within a day
#
#      host_response_rate host_acceptance_rate
# 7206               100%                  42%
# 7207               100%                  42%
# 7209               100%                  42%
# 7211               100%                  42%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5138    38997  Michelle  2009-09-16       within a day                78%
#
#      host_acceptance_rate
# 5138                  73%
#      host_id host_name  host_since  host_response_time host_response_rate  \
# 502    39377       Bob  2009-09-18  within a few hours               100%
# 540    39377       Bob  2009-09-18  within a few hours               100%
# 542    39377       Bob  2009-09-18  within a few hours               100%
#
#     host_acceptance_rate
# 502                 100%
# 540                 100%
# 542                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1394    44907     Brian  2009-10-10     within an hour               100%
#
#      host_acceptance_rate
# 1394                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3386    46879     Piper  2009-10-19                NaN                NaN
#
#      host_acceptance_rate
# 3386                  NaN
#       host_id    host_name  host_since host_response_time host_response_rate  \
# 4446    50866  SleepAfloat  2009-11-02     within an hour               100%
# 4477    50866  SleepAfloat  2009-11-02     within an hour               100%
# 4491    50866  SleepAfloat  2009-11-02     within an hour               100%
# 4499    50866  SleepAfloat  2009-11-02     within an hour               100%
# 4542    50866  SleepAfloat  2009-11-02     within an hour               100%
#
#      host_acceptance_rate
# 4446                  19%
# 4477                  19%
# 4491                  19%
# 4499                  19%
# 4542                  19%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 2639    50893     Chris  2009-11-02  within a few hours               100%
# 2763    50893     Chris  2009-11-02  within a few hours               100%
# 2797    50893     Chris  2009-11-02  within a few hours               100%
# 2798    50893     Chris  2009-11-02  within a few hours               100%
# 2799    50893     Chris  2009-11-02  within a few hours               100%
# 2800    50893     Chris  2009-11-02  within a few hours               100%
# 2824    50893     Chris  2009-11-02  within a few hours               100%
# 2868    50893     Chris  2009-11-02  within a few hours               100%
# 2871    50893     Chris  2009-11-02  within a few hours               100%
# 3464    50893     Chris  2009-11-02  within a few hours               100%
#
#      host_acceptance_rate
# 2639                 100%
# 2763                 100%
# 2797                 100%
# 2798                 100%
# 2799                 100%
# 2800                 100%
# 2824                 100%
# 2868                 100%
# 2871                 100%
# 3464                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 84     53050       Bob  2009-11-10     within an hour               100%
# 105    53050       Bob  2009-11-10     within an hour               100%
#
#     host_acceptance_rate
# 84                   NaN
# 105                  NaN
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3939    55603    Ashley  2009-11-18  within a few hours                90%
#
#      host_acceptance_rate
# 3939                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 2125    58235     Apryl  2009-11-28  within a few hours               100%
# 2296    58235     Apryl  2009-11-28  within a few hours               100%
#
#      host_acceptance_rate
# 2125                 100%
# 2296                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1975    62386      Lisa  2009-12-12     within an hour               100%
# 1979    62386      Lisa  2009-12-12     within an hour               100%
# 2017    62386      Lisa  2009-12-12     within an hour               100%
# 2048    62386      Lisa  2009-12-12     within an hour               100%
#
#      host_acceptance_rate
# 1975                 100%
# 1979                 100%
# 2017                 100%
# 2048                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4234    63525      Dayo  2009-12-16  within a few hours                90%
#
#      host_acceptance_rate
# 4234                  92%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1045    64929      Kate  2009-12-21                NaN                NaN
#
#      host_acceptance_rate
# 1045                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1302    64955       Beb  2009-12-22                NaN                NaN
#
#      host_acceptance_rate
# 1302                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1449    66145      Gene  2009-12-28     within an hour               100%
# 1450    66145      Gene  2009-12-28     within an hour               100%
# 2913    66145      Gene  2009-12-28     within an hour               100%
#
#      host_acceptance_rate
# 1449                 100%
# 1450                 100%
# 2913                 100%
#     host_id host_name  host_since  host_response_time host_response_rate  \
# 26    68155      Lori  2010-01-06  within a few hours               100%
#
#    host_acceptance_rate
# 26                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1692    68389      Elle  2010-01-06       within a day               100%
#
#      host_acceptance_rate
# 1692                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 965    68641    Angela  2010-01-07       within a day                70%
#
#     host_acceptance_rate
# 965                 100%
#       host_id     host_name  host_since host_response_time host_response_rate  \
# 5441    68870  Jim & Afiyah  2010-01-08     within an hour                99%
# 5476    68870  Jim & Afiyah  2010-01-08     within an hour                99%
#
#      host_acceptance_rate
# 5441                 100%
# 5476                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 6274    71783     Lance  2010-01-19       within a day                73%
# 6499    71783     Lance  2010-01-19       within a day                73%
# 6742    71783     Lance  2010-01-19       within a day                73%
# 6753    71783     Lance  2010-01-19       within a day                73%
# 6755    71783     Lance  2010-01-19       within a day                73%
# 6763    71783     Lance  2010-01-19       within a day                73%
# 6784    71783     Lance  2010-01-19       within a day                73%
# 6787    71783     Lance  2010-01-19       within a day                73%
# 6804    71783     Lance  2010-01-19       within a day                73%
# 6834    71783     Lance  2010-01-19       within a day                73%
#
#      host_acceptance_rate
# 6274                  91%
# 6499                  91%
# 6742                  91%
# 6753                  91%
# 6755                  91%
# 6763                  91%
# 6784                  91%
# 6787                  91%
# 6804                  91%
# 6834                  91%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2147    73359      Mary  2010-01-25     within an hour               100%
# 2156    73359      Mary  2010-01-25     within an hour               100%
#
#      host_acceptance_rate
# 2147                 100%
# 2156                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 498     74305     Darik  2010-01-27  within a few hours                94%
# 1086    74305     Darik  2010-01-27  within a few hours                94%
# 1210    74305     Darik  2010-01-27  within a few hours                94%
# 1239    74305     Darik  2010-01-27  within a few hours                94%
# 1242    74305     Darik  2010-01-27  within a few hours                94%
# 1244    74305     Darik  2010-01-27  within a few hours                94%
# 1282    74305     Darik  2010-01-27  within a few hours                94%
# 1288    74305     Darik  2010-01-27  within a few hours                94%
# 1289    74305     Darik  2010-01-27  within a few hours                94%
# 1290    74305     Darik  2010-01-27  within a few hours                94%
# 1291    74305     Darik  2010-01-27  within a few hours                94%
# 1306    74305     Darik  2010-01-27  within a few hours                94%
# 1307    74305     Darik  2010-01-27  within a few hours                94%
# 1308    74305     Darik  2010-01-27  within a few hours                94%
# 1309    74305     Darik  2010-01-27  within a few hours                94%
# 1314    74305     Darik  2010-01-27  within a few hours                94%
# 1320    74305     Darik  2010-01-27  within a few hours                94%
# 1328    74305     Darik  2010-01-27  within a few hours                94%
# 1331    74305     Darik  2010-01-27  within a few hours                94%
# 1339    74305     Darik  2010-01-27  within a few hours                94%
# 1350    74305     Darik  2010-01-27  within a few hours                94%
# 1352    74305     Darik  2010-01-27  within a few hours                94%
# 1354    74305     Darik  2010-01-27  within a few hours                94%
# 1357    74305     Darik  2010-01-27  within a few hours                94%
# 1362    74305     Darik  2010-01-27  within a few hours                94%
# 1370    74305     Darik  2010-01-27  within a few hours                94%
# 1395    74305     Darik  2010-01-27  within a few hours                94%
# 1403    74305     Darik  2010-01-27  within a few hours                94%
# 1426    74305     Darik  2010-01-27  within a few hours                94%
# 1428    74305     Darik  2010-01-27  within a few hours                94%
# 1531    74305     Darik  2010-01-27  within a few hours                94%
# 1570    74305     Darik  2010-01-27  within a few hours                94%
# 1605    74305     Darik  2010-01-27  within a few hours                94%
#
#      host_acceptance_rate
# 498                  100%
# 1086                 100%
# 1210                 100%
# 1239                 100%
# 1242                 100%
# 1244                 100%
# 1282                 100%
# 1288                 100%
# 1289                 100%
# 1290                 100%
# 1291                 100%
# 1306                 100%
# 1307                 100%
# 1308                 100%
# 1309                 100%
# 1314                 100%
# 1320                 100%
# 1328                 100%
# 1331                 100%
# 1339                 100%
# 1350                 100%
# 1352                 100%
# 1354                 100%
# 1357                 100%
# 1362                 100%
# 1370                 100%
# 1395                 100%
# 1403                 100%
# 1426                 100%
# 1428                 100%
# 1531                 100%
# 1570                 100%
# 1605                 100%
#      host_id   host_name  host_since host_response_time host_response_rate  \
# 96     79450  Brad & Liz  2010-02-09     within an hour               100%
# 126    79450  Brad & Liz  2010-02-09     within an hour               100%
#
#     host_acceptance_rate
# 96                  100%
# 126                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3347    83099      Cass  2010-02-19     within an hour                83%
#
#      host_acceptance_rate
# 3347                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4750    85770    Robert  2010-02-26  within a few hours               100%
# 4807    85770    Robert  2010-02-26  within a few hours               100%
# 4938    85770    Robert  2010-02-26  within a few hours               100%
# 4955    85770    Robert  2010-02-26  within a few hours               100%
# 4991    85770    Robert  2010-02-26  within a few hours               100%
#
#      host_acceptance_rate
# 4750                  96%
# 4807                  96%
# 4938                  96%
# 4955                  96%
# 4991                  96%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3633    86885    Monica  2010-03-01       within a day               100%
#
#      host_acceptance_rate
# 3633                 100%
#       host_id         host_name  host_since host_response_time  \
# 3563    87587  Margot & Anthony  2010-03-02       within a day
# 3638    87587  Margot & Anthony  2010-03-02       within a day
#
#      host_response_rate host_acceptance_rate
# 3563               100%                 100%
# 3638               100%                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2782    90437       Ian  2010-03-09     within an hour               100%
#
#      host_acceptance_rate
# 2782                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2053    91286   Tonyhai  2010-03-11                NaN                NaN
#
#      host_acceptance_rate
# 2053                 100%
#       host_id       host_name  host_since host_response_time  \
# 5777    93112  Henry And Lisa  2010-03-14     within an hour
#
#      host_response_rate host_acceptance_rate
# 5777               100%                  86%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 5436    93916  Francine  2010-03-15  within a few hours               100%
# 5479    93916  Francine  2010-03-15  within a few hours               100%
#
#      host_acceptance_rate
# 5436                  98%
# 5479                  98%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3421    95510     Peggy  2010-03-18       within a day               100%
#
#      host_acceptance_rate
# 3421                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4662    95959   Bandita  2010-03-19       within a day                50%
#
#      host_acceptance_rate
# 4662                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4848    97805   Stephen  2010-03-23     within an hour               100%
#
#      host_acceptance_rate
# 4848                   0%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4512    97821  Gretchen  2010-03-23       within a day               100%
#
#      host_acceptance_rate
# 4512                  94%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3083   102684    Amanda  2010-04-02  within a few hours                94%
#
#      host_acceptance_rate
# 3083                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1492   103427   Magalie  2010-04-04       within a day                87%
# 1495   103427   Magalie  2010-04-04       within a day                87%
#
#      host_acceptance_rate
# 1492                 100%
# 1495                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2838   106700       Zvi  2010-04-11                NaN                NaN
#
#      host_acceptance_rate
# 2838                  NaN
#      host_id host_name  host_since  host_response_time host_response_rate  \
# 214   106721     Paula  2010-04-11  within a few hours               100%
#
#     host_acceptance_rate
# 214                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 256   106972     Kelly  2010-04-11     within an hour               100%
#
#     host_acceptance_rate
# 256                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1453   107542    Arthur  2010-04-12     within an hour               100%
#
#      host_acceptance_rate
# 1453                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3006   107605        Al  2010-04-12  within a few hours                80%
#
#      host_acceptance_rate
# 3006                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 2325   110120   Melissa  2010-04-18  within a few hours               100%
#
#      host_acceptance_rate
# 2325                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2945   110248   Jamilah  2010-04-18     within an hour               100%
#
#      host_acceptance_rate
# 2945                 100%
#       host_id     host_name  host_since host_response_time host_response_rate  \
# 1858   110917  Erin & Vince  2010-04-19                NaN                NaN
#
#      host_acceptance_rate
# 1858                  NaN
#       host_id      host_name  host_since host_response_time  \
# 3316   112093  Roberta & Dan  2010-04-21     within an hour
#
#      host_response_rate host_acceptance_rate
# 3316               100%                 100%
#       host_id      host_name  host_since host_response_time  \
# 4036   113091  Nina And Mike  2010-04-24     within an hour
#
#      host_response_rate host_acceptance_rate
# 4036               100%                 100%
#       host_id        host_name  host_since  host_response_time  \
# 6661   115522  Nate + Danielle  2010-04-29  within a few hours
# 6811   115522  Nate + Danielle  2010-04-29  within a few hours
#
#      host_response_rate host_acceptance_rate
# 6661               100%                  89%
# 6811               100%                  89%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 6603   119019   Hermina  2010-05-05     within an hour               100%
# 6611   119019   Hermina  2010-05-05     within an hour               100%
# 6613   119019   Hermina  2010-05-05     within an hour               100%
# 6627   119019   Hermina  2010-05-05     within an hour               100%
# 6629   119019   Hermina  2010-05-05     within an hour               100%
# 6639   119019   Hermina  2010-05-05     within an hour               100%
# 6723   119019   Hermina  2010-05-05     within an hour               100%
# 6786   119019   Hermina  2010-05-05     within an hour               100%
# 6832   119019   Hermina  2010-05-05     within an hour               100%
#
#      host_acceptance_rate
# 6603                 100%
# 6611                 100%
# 6613                 100%
# 6627                 100%
# 6629                 100%
# 6639                 100%
# 6723                 100%
# 6786                 100%
# 6832                 100%
#       host_id             host_name  host_since host_response_time  \
# 3984   119381  Gordon And Alexandra  2010-05-06     within an hour
#
#      host_response_rate host_acceptance_rate
# 3984               100%                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 1292   119809     Weisi  2010-05-07  a few days or more                40%
#
#      host_acceptance_rate
# 1292                 100%
#       host_id       host_name  host_since host_response_time  \
# 4133   120731  Adrian Nichola  2010-05-08     within an hour
#
#      host_response_rate host_acceptance_rate
# 4133               100%                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5520   122982    Nadine  2010-05-11                NaN                NaN
#
#      host_acceptance_rate
# 5520                  NaN
#       host_id  host_name  host_since host_response_time host_response_rate  \
# 5518   128280  Elizabeth  2010-05-19     within an hour               100%
# 5538   128280  Elizabeth  2010-05-19     within an hour               100%
# 5591   128280  Elizabeth  2010-05-19     within an hour               100%
#
#      host_acceptance_rate
# 5518                 100%
# 5538                 100%
# 5591                 100%
#      host_id      host_name  host_since host_response_time host_response_rate  \
# 138   129014  Rob And Molly  2010-05-20     within an hour               100%
# 167   129014  Rob And Molly  2010-05-20     within an hour               100%
#
#     host_acceptance_rate
# 138                 100%
# 167                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2936   149118      Bart  2010-06-21                NaN                NaN
#
#      host_acceptance_rate
# 2936                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2035   157262    Visala  2010-07-02     within an hour               100%
#
#      host_acceptance_rate
# 2035                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5195   157679      Sara  2010-07-03                NaN                NaN
#
#      host_acceptance_rate
# 5195                  NaN
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 6228   159160   Deborah  2010-07-06  within a few hours               100%
#
#      host_acceptance_rate
# 6228                  83%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2995   160789   Darrell  2010-07-08                NaN                NaN
#
#      host_acceptance_rate
# 2995                  NaN
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 1037   164430      Jill  2010-07-12  within a few hours                90%
#
#      host_acceptance_rate
# 1037                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 409    165390      Seth  2010-07-13     within an hour               100%
# 423    165390      Seth  2010-07-13     within an hour               100%
# 3674   165390      Seth  2010-07-13     within an hour               100%
# 3753   165390      Seth  2010-07-13     within an hour               100%
# 3771   165390      Seth  2010-07-13     within an hour               100%
#
#      host_acceptance_rate
# 409                  100%
# 423                  100%
# 3674                 100%
# 3753                 100%
# 3771                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3496   167482       Ann  2010-07-15  within a few hours               100%
#
#      host_acceptance_rate
# 3496                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 6033   167745    Angela  2010-07-15       within a day                70%
#
#      host_acceptance_rate
# 6033                  91%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3378   168580      Glyn  2010-07-16     within an hour               100%
#
#      host_acceptance_rate
# 3378                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4731   170480     Chloe  2010-07-18       within a day               100%
#
#      host_acceptance_rate
# 4731                  29%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4050   174986    Robert  2010-07-20  within a few hours                90%
#
#      host_acceptance_rate
# 4050                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1801   178552   Rebecca  2010-07-23     within an hour               100%
#
#      host_acceptance_rate
# 1801                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5893   178829      John  2010-07-23                NaN                NaN
#
#      host_acceptance_rate
# 5893                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3469   179030   Harriet  2010-07-24     within an hour               100%
#
#      host_acceptance_rate
# 3469                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 168    179626     Susan  2010-07-24     within an hour               100%
# 3784   179626     Susan  2010-07-24     within an hour               100%
#
#      host_acceptance_rate
# 168                  100%
# 3784                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1931   180441      Pina  2010-07-25       within a day                86%
#
#      host_acceptance_rate
# 1931                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 328   181621   Barbara  2010-07-26     within an hour               100%
#
#     host_acceptance_rate
# 328                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5038   183065    Laurel  2010-07-28                NaN                NaN
#
#      host_acceptance_rate
# 5038                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 6075   184232    Ashley  2010-07-29                NaN                NaN
# 6122   184232    Ashley  2010-07-29                NaN                NaN
#
#      host_acceptance_rate
# 6075                  NaN
# 6122                  NaN
#      host_id       host_name  host_since  host_response_time  \
# 382   184382  Harry & Amanda  2010-07-29  within a few hours
#
#     host_response_rate host_acceptance_rate
# 382               100%                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3554   186257    Nicole  2010-07-30                NaN                NaN
#
#      host_acceptance_rate
# 3554                  NaN
#       host_id         host_name  host_since  host_response_time  \
# 2456   187753  Kevin & Jennifer  2010-08-01  within a few hours
#
#      host_response_rate host_acceptance_rate
# 2456               100%                 100%
#      host_id host_name  host_since  host_response_time host_response_rate  \
# 351   189356   Michael  2010-08-02  within a few hours               100%
#
#     host_acceptance_rate
# 351                 100%
#       host_id    host_name  host_since host_response_time host_response_rate  \
# 4724   189855  Marla & Coe  2010-08-03     within an hour               100%
#
#      host_acceptance_rate
# 4724                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 1788   192355      Jane  2010-08-05  within a few hours               100%
#
#      host_acceptance_rate
# 1788                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2107   193689      Eric  2010-08-06     within an hour               100%
#
#      host_acceptance_rate
# 2107                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4112   197327   Melissa  2010-08-10  within a few hours               100%
# 4155   197327   Melissa  2010-08-10  within a few hours               100%
#
#      host_acceptance_rate
# 4112                  92%
# 4155                  92%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3276   197690  Trishann  2010-08-10                NaN                NaN
# 3652   197690  Trishann  2010-08-10                NaN                NaN
# 3654   197690  Trishann  2010-08-10                NaN                NaN
#
#      host_acceptance_rate
# 3276                  NaN
# 3652                  NaN
# 3654                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5374   204485    DeAnna  2010-08-17       within a day               100%
#
#      host_acceptance_rate
# 5374                  25%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1682   204975  Philippe  2010-08-18                NaN                NaN
#
#      host_acceptance_rate
# 1682                  NaN
#     host_id         host_name  host_since host_response_time  \
# 95   205007  Martin And Taryn  2010-08-18       within a day
#
#    host_response_rate host_acceptance_rate
# 95               100%                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 5524   205107      Atef  2010-08-18     within an hour               100%
# 5541   205107      Atef  2010-08-18     within an hour               100%
#
#      host_acceptance_rate
# 5524                  88%
# 5541                  88%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1863   205325      Teri  2010-08-18                NaN                NaN
#
#      host_acceptance_rate
# 1863                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1861   205412       Meg  2010-08-18     within an hour               100%
# 1864   205412       Meg  2010-08-18     within an hour               100%
# 1873   205412       Meg  2010-08-18     within an hour               100%
#
#      host_acceptance_rate
# 1861                 100%
# 1864                 100%
# 1873                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3999   206353     Perry  2010-08-19     within an hour               100%
#
#      host_acceptance_rate
# 3999                  96%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 5129   206505    Cecile  2010-08-19  within a few hours               100%
#
#      host_acceptance_rate
# 5129                  50%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3228   207419   Hayoung  2010-08-20  within a few hours                90%
#
#      host_acceptance_rate
# 3228                 100%
#       host_id       host_name  host_since host_response_time  \
# 3881   207475  Danielle&Peder  2010-08-20     within an hour
#
#      host_response_rate host_acceptance_rate
# 3881               100%                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3442   208959       Val  2010-08-22     within an hour               100%
#
#      host_acceptance_rate
# 3442                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1177   209571    Cheryl  2010-08-22     within an hour               100%
#
#      host_acceptance_rate
# 1177                 100%
#       host_id     host_name  host_since  host_response_time  \
# 3417   212404  Piper + Kent  2010-08-25  within a few hours
#
#      host_response_rate host_acceptance_rate
# 3417               100%                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4622   212445      Emma  2010-08-25     within an hour               100%
# 4627   212445      Emma  2010-08-25     within an hour               100%
# 4708   212445      Emma  2010-08-25     within an hour               100%
#
#      host_acceptance_rate
# 4622                  98%
# 4627                  98%
# 4708                  98%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 3600   212740   Shalini  2010-08-25     within an hour                90%
#
#      host_acceptance_rate
# 3600                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3234   215230     Carol  2010-08-28  within a few hours               100%
# 3243   215230     Carol  2010-08-28  within a few hours               100%
# 3246   215230     Carol  2010-08-28  within a few hours               100%
# 3249   215230     Carol  2010-08-28  within a few hours               100%
#
#      host_acceptance_rate
# 3234                 100%
# 3243                 100%
# 3246                 100%
# 3249                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1151   220013      Erik  2010-09-01                NaN                NaN
#
#      host_acceptance_rate
# 1151                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1100   222538     Suryo  2010-09-03                NaN                NaN
#
#      host_acceptance_rate
# 1100                  NaN
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4236   224090    Tricia  2010-09-04     within an hour               100%
#
#      host_acceptance_rate
# 4236                  71%
#       host_id    host_name  host_since  host_response_time host_response_rate  \
# 3027   225830  Lee & Steve  2010-09-06  within a few hours               100%
# 3029   225830  Lee & Steve  2010-09-06  within a few hours               100%
#
#      host_acceptance_rate
# 3027                 100%
# 3029                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1135   225845     Gavin  2010-09-06     within an hour                96%
# 2558   225845     Gavin  2010-09-06     within an hour                96%
#
#      host_acceptance_rate
# 1135                 100%
# 2558                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 777   228678     Katie  2010-09-08       within a day               100%
#
#     host_acceptance_rate
# 777                  NaN
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4197   228845    Jeremy  2010-09-08  within a few hours               100%
# 4209   228845    Jeremy  2010-09-08  within a few hours               100%
#
#      host_acceptance_rate
# 4197                  56%
# 4209                  56%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 1891   230140     Marie  2010-09-10     within an hour               100%
#
#      host_acceptance_rate
# 1891                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 2237   236709     Mandy  2010-09-16     within an hour               100%
# 2245   236709     Mandy  2010-09-16     within an hour               100%
#
#      host_acceptance_rate
# 2237                 100%
# 2245                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4037   236790       Ann  2010-09-16     within an hour               100%
#
#      host_acceptance_rate
# 4037                 100%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 228   238431     Brian  2010-09-18     within an hour               100%
#
#     host_acceptance_rate
# 228                 100%
#       host_id       host_name  host_since  host_response_time  \
# 3667   238982  Maria & Graham  2010-09-19  within a few hours
# 3694   238982  Maria & Graham  2010-09-19  within a few hours
# 3786   238982  Maria & Graham  2010-09-19  within a few hours
#
#      host_response_rate host_acceptance_rate
# 3667                97%                 100%
# 3694                97%                 100%
# 3786                97%                 100%
#     host_id     host_name  host_since  host_response_time host_response_rate  \
# 10   239585  Ray & Eileen  2010-09-19  within a few hours               100%
#
#    host_acceptance_rate
# 10                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 6838   239850  Theodore  2010-09-20       within a day                83%
#
#      host_acceptance_rate
# 6838                   0%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 3497   242188  Jennifer  2010-09-22  a few days or more                43%
#
#      host_acceptance_rate
# 3497                 100%
#       host_id host_name  host_since host_response_time host_response_rate  \
# 4304   246083   Lindsey  2010-09-26                NaN                NaN
#
#      host_acceptance_rate
# 4304                  NaN
#       host_id         host_name  host_since host_response_time  \
# 1545   247975  Kevin And Monica  2010-09-28     within an hour
# 2420   247975  Kevin And Monica  2010-09-28     within an hour
#
#      host_response_rate host_acceptance_rate
# 1545               100%                 100%
# 2420               100%                 100%
#       host_id host_name  host_since  host_response_time host_response_rate  \
# 4614   255183  Michelle  2010-10-06  within a few hours                92%
# 4615   255183  Michelle  2010-10-06  within a few hours                92%
# 4634   255183  Michelle  2010-10-06  within a few hours                92%
# 4635   255183  Michelle  2010-10-06  within a few hours                92%
# 4699   255183  Michelle  2010-10-06  within a few hours                92%
#
#      host_acceptance_rate
# 4614                  96%
# 4615                  96%
# 4634                  96%
# 4635                  96%
# 4699                  96%
#      host_id host_name  host_since host_response_time host_response_rate  \
# 136   256203   Shannon  2010-10-07       within a day                63%
#
#     host_acceptance_rate
# 136                 100%
# ...
#
#      host_acceptance_rate
# 7362                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6599  84786354   Novlett  2016-07-19     within an hour               100%
# 6659  84786354   Novlett  2016-07-19     within an hour               100%
#
#      host_acceptance_rate
# 6599                 100%
# 6659                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4968  84808632  Aurelien  2016-07-19     within an hour               100%
#
#      host_acceptance_rate
# 4968                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4468  84922021   Lindsay  2016-07-20     within an hour               100%
#
#      host_acceptance_rate
# 4468                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5310  84942880   Kristin  2016-07-20     within an hour               100%
#
#      host_acceptance_rate
# 5310                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6248  84987667      Anne  2016-07-20     within an hour               100%
#
#      host_acceptance_rate
# 6248                  80%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5969  84991497      Qing  2016-07-20     within an hour               100%
# 7337  84991497      Qing  2016-07-20     within an hour               100%
#
#      host_acceptance_rate
# 5969                 100%
# 7337                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 4289  85019755     Kavya  2016-07-21  within a few hours                92%
#
#      host_acceptance_rate
# 4289                  42%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 5526  85308564       Kim  2016-07-22  a few days or more                17%
#
#      host_acceptance_rate
# 5526                 100%
#        host_id  host_name  host_since host_response_time host_response_rate  \
# 6043  86400771  Elizabeth  2016-07-27     within an hour                97%
#
#      host_acceptance_rate
# 6043                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6158  86416621    Alexis  2016-07-27       within a day               100%
#
#      host_acceptance_rate
# 6158                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5875  86576589   Janiene  2016-07-28                NaN                NaN
#
#      host_acceptance_rate
# 5875                  NaN
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 6068  86755107    Sushma  2016-07-29  within a few hours                82%
#
#      host_acceptance_rate
# 6068                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4251  86931675     Maren  2016-07-30     within an hour               100%
# 4315  86931675     Maren  2016-07-30     within an hour               100%
#
#      host_acceptance_rate
# 4251                 100%
# 4315                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5370  86955930     Salma  2016-07-30                NaN                NaN
#
#      host_acceptance_rate
# 5370                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5869  87226338     Coach  2016-08-01                NaN                NaN
#
#      host_acceptance_rate
# 5869                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6914  87245627    Nastia  2016-08-01                NaN                NaN
#
#      host_acceptance_rate
# 6914                  NaN
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 5449  87858249  Sulaiman  2016-08-04  within a few hours                94%
#
#      host_acceptance_rate
# 5449                  94%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5262  88129265     Jason  2016-08-05     within an hour               100%
#
#      host_acceptance_rate
# 5262                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 6273  88157615   Krystal  2016-08-05  a few days or more                40%
#
#      host_acceptance_rate
# 6273                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5924  88360952      Tony  2016-08-06     within an hour               100%
#
#      host_acceptance_rate
# 5924                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4852  88372372    Lauren  2016-08-06     within an hour               100%
#
#      host_acceptance_rate
# 4852                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 7363  88521075    Masoud  2016-08-07  within a few hours               100%
#
#      host_acceptance_rate
# 7363                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6484  88543034    Robert  2016-08-07     within an hour                83%
#
#      host_acceptance_rate
# 6484                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 7250  88908642     Kevin  2016-08-09     within an hour               100%
#
#      host_acceptance_rate
# 7250                  88%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 6378  89089164     Ellen  2016-08-10  within a few hours               100%
#
#      host_acceptance_rate
# 6378                 100%
#        host_id  host_name  host_since host_response_time host_response_rate  \
# 5644  89153895  Elizabeth  2016-08-10     within an hour               100%
#
#      host_acceptance_rate
# 5644                 100%
#        host_id         host_name  host_since host_response_time  \
# 6539  89209244  Valerie And Joel  2016-08-10       within a day
#
#      host_response_rate host_acceptance_rate
# 6539                67%                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 4093  89230454      Asad  2016-08-10  within a few hours               100%
#
#      host_acceptance_rate
# 4093                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 4425  89613233    Krista  2016-08-13  within a few hours                94%
#
#      host_acceptance_rate
# 4425                  73%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 6282  89873768   Praveen  2016-08-14  within a few hours               100%
#
#      host_acceptance_rate
# 6282                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 7372  89884123     Craig  2016-08-14  within a few hours               100%
#
#      host_acceptance_rate
# 7372                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 7368  90052719      Pohl  2016-08-15       within a day               100%
#
#      host_acceptance_rate
# 7368                  50%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5383  90216774   Natalia  2016-08-16                NaN                NaN
#
#      host_acceptance_rate
# 5383                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4793  90491687      John  2016-08-17     within an hour               100%
#
#      host_acceptance_rate
# 4793                 100%
#        host_id      host_name  host_since host_response_time  \
# 7389  90497470  Sofia And Kim  2016-08-17     within an hour
#
#      host_response_rate host_acceptance_rate
# 7389               100%                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6027  90512786     Ainur  2016-08-17     within an hour               100%
# 6163  90512786     Ainur  2016-08-17     within an hour               100%
# 6268  90512786     Ainur  2016-08-17     within an hour               100%
#
#      host_acceptance_rate
# 6027                  79%
# 6163                  79%
# 6268                  79%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5533  90526463    Darren  2016-08-17                NaN                NaN
#
#      host_acceptance_rate
# 5533                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6071  90540199    Ulrich  2016-08-17     within an hour               100%
#
#      host_acceptance_rate
# 6071                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 7375  90615440   Maureen  2016-08-18       within a day               100%
#
#      host_acceptance_rate
# 7375                  67%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6319  90839028     Jiayi  2016-08-19     within an hour               100%
#
#      host_acceptance_rate
# 6319                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 6030  91070657     Manan  2016-08-21  within a few hours               100%
#
#      host_acceptance_rate
# 6030                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 7108  91096414    Lauren  2016-08-21     within an hour               100%
#
#      host_acceptance_rate
# 7108                  79%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6583  91099010      Mary  2016-08-21     within an hour               100%
# 6584  91099010      Mary  2016-08-21     within an hour               100%
# 6592  91099010      Mary  2016-08-21     within an hour               100%
#
#      host_acceptance_rate
# 6583                 100%
# 6584                 100%
# 6592                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4288  91169115     Ellen  2016-08-21     within an hour               100%
# 4293  91169115     Ellen  2016-08-21     within an hour               100%
#
#      host_acceptance_rate
# 4288                 100%
# 4293                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4138  91197438   Vinayak  2016-08-21                NaN                NaN
#
#      host_acceptance_rate
# 4138                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6464  91411121      Moon  2016-08-23     within an hour               100%
#
#      host_acceptance_rate
# 6464                 100%
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 6651  91521392    Joseph  2016-08-23  within a few hours                67%
# 6747  91521392    Joseph  2016-08-23  within a few hours                67%
#
#      host_acceptance_rate
# 6651                 100%
# 6747                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5330  91548283   Anthony  2016-08-23     within an hour               100%
# 5355  91548283   Anthony  2016-08-23     within an hour               100%
#
#      host_acceptance_rate
# 5330                 100%
# 5355                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6690  91831056     Yizuo  2016-08-25                NaN                NaN
#
#      host_acceptance_rate
# 6690                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6488  91855319        公主  2016-08-25     within an hour               100%
# 7392  91855319        公主  2016-08-25     within an hour               100%
#
#      host_acceptance_rate
# 6488                 100%
# 7392                 100%
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6339  91968083   Maureen  2016-08-26                NaN                NaN
#
#      host_acceptance_rate
# 6339                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6113  92196747      Neza  2016-08-27                NaN                NaN
#
#      host_acceptance_rate
# 6113                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4357  92648590      Paul  2016-08-30                NaN                NaN
#
#      host_acceptance_rate
# 4357                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 7379  92650841     Chloe  2016-08-30                NaN                NaN
#
#      host_acceptance_rate
# 7379                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4839  92663980      Fadi  2016-08-30                NaN                NaN
#
#      host_acceptance_rate
# 4839                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6619  92712021     Zulma  2016-08-30                NaN                NaN
#
#      host_acceptance_rate
# 6619                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6952  92878185    Victor  2016-08-31                NaN                NaN
# 6964  92878185    Victor  2016-08-31                NaN                NaN
#
#      host_acceptance_rate
# 6952                  NaN
# 6964                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5933  93031650       Kay  2016-09-01                NaN                NaN
#
#      host_acceptance_rate
# 5933                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5720  93035834     Erika  2016-09-01                NaN                NaN
# 5828  93035834     Erika  2016-09-01                NaN                NaN
#
#      host_acceptance_rate
# 5720                  NaN
# 5828                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5712  93051119      Mary  2016-09-01                NaN                NaN
#
#      host_acceptance_rate
# 5712                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6436  93115614     Selim  2016-09-02                NaN                NaN
#
#      host_acceptance_rate
# 6436                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 4766  93363670     Mason  2016-09-03                NaN                NaN
#
#      host_acceptance_rate
# 4766                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5440  93364702      Aria  2016-09-03                NaN                NaN
#
#      host_acceptance_rate
# 5440                  NaN
#        host_id  host_name  host_since host_response_time host_response_rate  \
# 4389  93512984  Valentino  2016-09-04                NaN                NaN
#
#      host_acceptance_rate
# 4389                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 3925  93635490     Isaac  2016-09-05                NaN                NaN
#
#      host_acceptance_rate
# 3925                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6459  93674064  Benjamin  2016-09-05                NaN                NaN
#
#      host_acceptance_rate
# 6459                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 5517  93820834     Maria  2016-09-06                NaN                NaN
#
#      host_acceptance_rate
# 5517                  NaN
#        host_id host_name  host_since host_response_time host_response_rate  \
# 6607  93854106    Pastor  2016-09-06                NaN                NaN
#
#      host_acceptance_rate
# 6607                  NaN

# %% [markdown]
# **Since null values are consitstent through out all hosts postings we have to do it manually**

# %%
df[['host_id','host_name','host_since','host_response_time','host_response_rate','host_acceptance_rate']]
# Out:
#        host_id host_name  host_since  host_response_time host_response_rate  \
# 0       956883     Maija  2011-08-11  within a few hours                96%
# 1      5177328    Andrea  2013-02-21      within an hour                98%
# 2     16708587      Jill  2014-06-12  within a few hours                67%
# 3      9851441     Emily  2013-11-06                 NaN                NaN
# 4      1452570     Emily  2011-11-29      within an hour               100%
# ...        ...       ...         ...                 ...                ...
# 7398  19246369       Joe  2014-07-31      within an hour                96%
# 7399  37366454       Ivy  2015-07-02  a few days or more                10%
# 7400  11311919      Vera  2014-01-14        within a day                78%
# 7401  74318064      Medi  2016-05-27      within an hour               100%
# 7402  42070843    Rachel  2015-08-20      within an hour               100%
#
#      host_acceptance_rate
# 0                    100%
# 1                    100%
# 2                    100%
# 3                     NaN
# 4                     NaN
# ...                   ...
# 7398                 100%
# 7399                  83%
# 7400                  50%
# 7401                  96%
# 7402                  95%
#
# [7403 rows x 6 columns]

# %%
# fill the host name null values with none
df['host_name'].isnull().sum()
df['host_name'].fillna('none',inplace = True)

# %%
# change host_since to date_time format
df['host_since'].isnull().sum()
df['host_since']= pd.to_datetime(df['host_since'])
# fill missing values with the median
df['host_since'].fillna(df['host_since'].median,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-126-29998a1445b1> in <module>
#       1 # change host_since to date_time format
#       2 df['host_since'].isnull().sum()
# ----> 3 df['host_since']= pd.to_datetime(df['host_since'])
#       4 # fill missing values with the median
#       5 df['host_since'].fillna(df['host_since'].median,inplace = True)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     726             result = arg.map(cache_array)
#     727         else:
# --> 728             values = convert_listlike(arg._values, format)
#     729             result = arg._constructor(values, index=arg.index, name=arg.name)
#     730     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     445             errors=errors,
#     446             require_iso8601=require_iso8601,
# --> 447             allow_object=True,
#     448         )
#     449
#
# /usr/local/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1852             dayfirst=dayfirst,
#    1853             yearfirst=yearfirst,
# -> 1854             require_iso8601=require_iso8601,
#    1855         )
#    1856     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: <class 'method'> is not convertible to datetime

# %%
# fill host_response_time with unknown since we don't know response time
df['host_response_time'].fillna('unknown',inplace = True)

# %%
# strip the percentage sign before filling the missing values
df['host_response_rate'] = df['host_response_rate'].apply(lambda x: int(x.strip('%')) if type(x) == str else None)
# fill the missing value with the median
df['host_response_rate'].fillna(df['host_response_rate'].median(),inplace = True)

# %%
# strip the percentage sign before filling the missing values
df['host_acceptance_rate'] = df['host_acceptance_rate'].apply(lambda x: int(x.strip('%')) if type(x) == str else None)
# fill the missing value with the median
df['host_acceptance_rate'].fillna(df['host_acceptance_rate'].median(), inplace = True)

# %%
# change t , f values to boolean 0 , 1
df['host_is_superhost'] = df['host_is_superhost'].apply(lambda x : 1 if x == 't' else 0)
df['host_is_superhost'].isnull().sum()
df['host_is_superhost'].fillna(df['host_is_superhost'].mode(),inplace=True)

# %%
#delete unnacassary columns
del df['host_neighbourhood']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**host_listings_count**|`float64`|replace null with mean|
# |**host_total_listings_count**|`float64`|replace null with mean|
# |**host_has_profile_pic**|`object`|replace null with none|
# |**host_identity_verified**|`object`|replace from median|
# |**host_verifications**|`object`|replace from verification count|
# |**market**|`object`|delete to avoid redundency|

# %%
#get info
df['host_listings_count'].value_counts()
df['host_listings_count'].isnull().sum()
# replace the null values with the mean
df['host_listings_count'].fillna(df['host_listings_count'].mean(),inplace = True)
#round the values
df['host_listings_count'] = df['host_listings_count'].apply(lambda x : round(x))

# %%
df['host_total_listings_count'].head()
df['host_total_listings_count'].value_counts()
df['host_total_listings_count'].isnull().sum()
#replace the null values with the mean
df['host_total_listings_count'].fillna(df['host_total_listings_count'].mean(),inplace = True)
#round the values for easier computation
df['host_total_listings_count'] = df['host_total_listings_count'].apply(lambda x : round(x))

# %%
df['host_has_profile_pic'].head()
df['host_has_profile_pic'].isnull().sum()
# change t , f values to boolean 0 , 1 and missing values to 0 
df['host_has_profile_pic'] = df['host_has_profile_pic'].apply(lambda x : 1 if x == 't' else 0)

# %%
df['host_identity_verified'].head()
df['host_identity_verified'].isnull().sum()
# change t , f values to boolean 0 , 1 and missing values to 0 
df['host_identity_verified'] = df['host_identity_verified'].apply(lambda x : 1 if x == 't' else 0)

# %%
df['host_verifications'].head()
# get the count of host_verifications insted of list
df['host_verifications_count'] = df['host_verifications'].apply(lambda x : len(x))

# %%
df['host_verifications_count'].value_counts()
# Out:
# 36    1208
# 38    1124
# 48    1106
# 29     953
# 50     685
#       ...
# 19       1
# 31       1
# 16       1
# 12       1
# 87       1
# Name: host_verifications_count, Length: 64, dtype: int64

# %%
df['market'].head()
df['market'].value_counts()
# Out:
# Seattle                  3818
# Boston                   3568
# San Francisco               1
# Other (Domestic)            1
# Other (International)       1
# Name: market, dtype: int64

# %%
del df['market']
del df['host_verifications']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7403 entries, 0 to 7402
# Data columns (total 77 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                7403 non-null   int64
#  1   scrape_id                         7403 non-null   int64
#  2   last_scraped                      7403 non-null   object
#  3   name                              7403 non-null   object
#  4   host_id                           7403 non-null   int64
#  5   host_name                         7403 non-null   object
#  6   host_since                        7403 non-null   object
#  7   host_location                     7403 non-null   object
#  8   host_response_time                7403 non-null   object
#  9   host_response_rate                7403 non-null   float64
#  10  host_acceptance_rate              7403 non-null   float64
#  11  host_is_superhost                 7403 non-null   int64
#  12  host_listings_count               7403 non-null   int64
#  13  host_total_listings_count         7403 non-null   int64
#  14  host_has_profile_pic              7403 non-null   int64
#  15  host_identity_verified            7403 non-null   int64
#  16  street                            7403 non-null   object
#  17  neighbourhood                     7403 non-null   object
#  18  zipcode                           7403 non-null   object
#  19  smart_location                    7403 non-null   object
#  20  latitude                          7403 non-null   float64
#  21  longitude                         7403 non-null   float64
#  22  is_location_exact                 7403 non-null   int64
#  23  property_type                     7399 non-null   object
#  24  room_type                         7403 non-null   object
#  25  accommodates                      7403 non-null   int64
#  26  bathrooms                         7373 non-null   float64
#  27  bedrooms                          7387 non-null   float64
#  28  beds                              7393 non-null   float64
#  29  bed_type                          7403 non-null   object
#  30  amenities                         7403 non-null   object
#  31  price                             7403 non-null   object
#  32  weekly_price                      2901 non-null   object
#  33  monthly_price                     2405 non-null   object
#  34  security_deposit                  3208 non-null   object
#  35  cleaning_fee                      5266 non-null   object
#  36  guests_included                   7403 non-null   int64
#  37  extra_people                      7403 non-null   object
#  38  minimum_nights                    7403 non-null   int64
#  39  maximum_nights                    7403 non-null   int64
#  40  calendar_updated                  7403 non-null   object
#  41  has_availability                  3818 non-null   object
#  42  availability_30                   7403 non-null   int64
#  43  availability_60                   7403 non-null   int64
#  44  availability_90                   7403 non-null   int64
#  45  availability_365                  7403 non-null   int64
#  46  calendar_last_scraped             7403 non-null   object
#  47  number_of_reviews                 7403 non-null   int64
#  48  first_review                      6020 non-null   object
#  49  last_review                       6020 non-null   object
#  50  review_scores_rating              5943 non-null   float64
#  51  review_scores_accuracy            5922 non-null   float64
#  52  review_scores_cleanliness         5932 non-null   float64
#  53  review_scores_checkin             5925 non-null   float64
#  54  review_scores_communication       5934 non-null   float64
#  55  review_scores_location            5926 non-null   float64
#  56  review_scores_value               5926 non-null   float64
#  57  requires_license                  7403 non-null   object
#  58  jurisdiction_names                3818 non-null   object
#  59  instant_bookable                  7403 non-null   object
#  60  cancellation_policy               7403 non-null   object
#  61  require_guest_profile_picture     7403 non-null   object
#  62  require_guest_phone_verification  7403 non-null   object
#  63  calculated_host_listings_count    7403 non-null   int64
#  64  reviews_per_month                 6020 non-null   float64
#  65  access                            2096 non-null   object
#  66  interaction                       2031 non-null   object
#  67  house_rules                       2393 non-null   object
#  68  summary_wc                        7403 non-null   int64
#  69  space_wc                          7403 non-null   int64
#  70  description_wc                    7403 non-null   int64
#  71  neighborhood_overview_wc          7403 non-null   int64
#  72  transit_wc                        7403 non-null   int64
#  73  host_about_wc                     7403 non-null   int64
#  74  notes_wc                          7403 non-null   int64
#  75  host_match                        7403 non-null   int64
#  76  host_verifications_count          7403 non-null   int64
# dtypes: float64(15), int64(28), object(34)
# memory usage: 4.3+ MB

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**property_type**|`float64`|replace null with mean|
# |**room_type**|`float64`|replace null with mean|
# |**accommodates**|`int64`|replace null with none|
# |**bathrooms**|`float64`|replace from median|
# |**bedrooms**|`float64`|delete to avoid redundency|
# |**beds**|`float64`|delete to avoid redundency|
# |**bed_type**|`object`|delete to avoid redundency|
# |**amenities**|`object`|delete to avoid redundency|

# %%
df[['property_type','room_type','accommodates','bathrooms','bedrooms']]
# Out:
#      property_type        room_type  accommodates  bathrooms  bedrooms
# 0        Apartment  Entire home/apt             4        1.0       1.0
# 1        Apartment  Entire home/apt             4        1.0       1.0
# 2            House  Entire home/apt            11        4.5       5.0
# 3        Apartment  Entire home/apt             3        1.0       0.0
# 4            House  Entire home/apt             6        2.0       3.0
# ...            ...              ...           ...        ...       ...
# 7398     Apartment     Private room             3        1.0       1.0
# 7399     Apartment     Private room             2        1.0       1.0
# 7400     Apartment  Entire home/apt             4        1.0       1.0
# 7401     Apartment     Private room             2        1.0       1.0
# 7402     Apartment     Private room             2        1.0       1.0
#
# [7403 rows x 5 columns]

# %%
#get info property_type
df['property_type'].value_counts()
df['property_type'].isnull().sum()
#fill the missing values with the mode
df['property_type'].fillna(df['property_type'].mode()[0],inplace=True)
df['property_type'].isnull().sum()
# Out:
# 0

# %%
#get info room_type
df['room_type'].head()
df['room_type'].value_counts()
df['room_type'].isnull().sum()
# Out:
# 0

# %%
# get info accommodates
df['accommodates'].head()
df['accommodates'].value_counts()
df['accommodates'].isnull().sum()
# Out:
# 0

# %%
# get into bathrooms
df['bathrooms'].head()
df['bathrooms'].value_counts()
df['bathrooms'].isnull().sum()
#fill the missing values using the mode
df['bathrooms'].fillna(df['bathrooms'].mode()[0],inplace=True)
df['bathrooms'].isnull().sum()
# Out:
# 0

# %%
#get info bedrooms
df['bedrooms'].head()
df['bedrooms'].value_counts()
df['bedrooms'].isnull().sum()
#fill the missing values using the mode
df['bedrooms'].fillna(df['bedrooms'].mode()[0],inplace=True)
df['bedrooms'].isnull().sum()
# Out:
# 0

# %%
df['beds'].head()
df['beds'].value_counts()
df['beds'].isnull().sum()
df['beds'].fillna(df['beds'].mode()[0],inplace=True)
df['beds'].isnull().sum()
# Out:
# 0

# %%
df['bed_type'].head()
df['bed_type'].value_counts()
df['bed_type'].isnull().sum()
# Out:
# 0

# %%
df['amenities'].head()
df['amenities_count'] = df['amenities'].apply(lambda x : len(x.split(',')) if type(x) == str else 0)
df['amenities_count'].value_counts()
df['amenities_count'].isnull().sum()
# Out:
# 0

# %%
#delete unnassary columns
del df['amenities']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**price**|`object`|clean|
# |**weekly_price**|`object`|delete due to many missing values|
# |**monthly_price**|`object`|delete due to many missing values|
# |**security_deposit**|`object`|replace null values with 0|
# |**cleaning_fee**|`object`|replace null values with 0|
# |**guests_included**|`int64`|clean|
# |**extra_people**|`object`|clean|

# %%
df[['price','weekly_price','monthly_price','security_deposit','cleaning_fee','guests_included']]
# Out:
#         price weekly_price monthly_price security_deposit cleaning_fee  \
# 0      $85.00          NaN           NaN              NaN          NaN
# 1     $150.00    $1,000.00     $3,000.00          $100.00       $40.00
# 2     $975.00          NaN           NaN        $1,000.00      $300.00
# 3     $100.00      $650.00     $2,300.00              NaN          NaN
# 4     $450.00          NaN           NaN          $700.00      $125.00
# ...       ...          ...           ...              ...          ...
# 7398   $69.00          NaN           NaN           $95.00          NaN
# 7399  $150.00          NaN           NaN          $100.00       $15.00
# 7400  $198.00          NaN           NaN              NaN          NaN
# 7401   $65.00          NaN           NaN          $100.00          NaN
# 7402   $65.00          NaN           NaN              NaN       $25.00
#
#       guests_included
# 0                   2
# 1                   1
# 2                  10
# 3                   1
# 4                   6
# ...               ...
# 7398                1
# 7399                1
# 7400                1
# 7401                1
# 7402                1
#
# [7403 rows x 6 columns]

# %%
# get info fix
df['price'].isnull().sum()
# remove the dollar sign and comma to transorm to float
df['price'] = df['price'].apply(lambda x : float(x.strip('$').replace(',','')))

# %%
# replace with 0 and remove the dollar sign and comma to transorm to float
df['security_deposit'] = df['security_deposit'].apply(lambda x : float(x.strip('$').replace(',','')) if type(x)==str else 0)

# %%
# replace with 0 and remove the dollar sign and comma to transorm to float
df['cleaning_fee'].isnull().sum()
df['cleaning_fee'] = df['cleaning_fee'].apply(lambda x : float(x.strip('$').replace(',','')) if type(x)==str else 0)

# %%
#check column
df['guests_included'].isnull().sum()
df['guests_included'].value_counts()
# Out:
# 1     4882
# 2     1543
# 4      406
# 0      180
# 3      171
# 6      108
# 5       56
# 8       30
# 7       15
# 10       3
# 9        3
# 12       2
# 15       1
# 11       1
# 14       1
# 13       1
# Name: guests_included, dtype: int64

# %%
#remove the dollar sign and comma to transorm to float
df['extra_people'] = df['extra_people'].apply(lambda x : float(x.strip('$').replace(',','')) if type(x)==str else 0)

# %%
#delete unncessary columns
del df['weekly_price']
del df['monthly_price']

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**minimum_nights**|`int64`|clean|
# |**maximum_nights**|`int64`|clean|
# |**calendar_updated**|`object`|clean|
# |**has_availability**|`object`|make bool|
# |**availability_30**|`int64`|clean|
# |**availability_60**|`int64`|clean|
# |**availability_90**|`int64`|clean|
# |**availability_365**|`int64`|clean|
# |**calendar_last_scraped**|`object`|delete to avoid redundency|

# %%
df[['minimum_nights','maximum_nights','calendar_updated','has_availability','availability_30','availability_60','availability_90','availability_365','calendar_last_scraped']]
# Out:
#       minimum_nights  maximum_nights calendar_updated has_availability  \
# 0                  1             365      4 weeks ago                t
# 1                  2              90            today                t
# 2                  4              30      5 weeks ago                t
# 3                  1            1125     6 months ago                t
# 4                  1            1125      7 weeks ago                t
# ...              ...             ...              ...              ...
# 7398               2            1125       5 days ago              NaN
# 7399               3             365            never              NaN
# 7400               3              12      3 weeks ago              NaN
# 7401               1              13            today              NaN
# 7402               1            1125            today              NaN
#
#       availability_30  availability_60  availability_90  availability_365  \
# 0                  14               41               71               346
# 1                  13               13               16               291
# 2                   1                6               17               220
# 3                   0                0                0               143
# 4                  30               60               90               365
# ...               ...              ...              ...               ...
# 7398               21               51               81               356
# 7399               29               59               89               364
# 7400                0               15               40                40
# 7401                5                5                5               253
# 7402               17               45               75               165
#
#      calendar_last_scraped
# 0               2016-01-04
# 1               2016-01-04
# 2               2016-01-04
# 3               2016-01-04
# 4               2016-01-04
# ...                    ...
# 7398            2016-09-06
# 7399            2016-09-06
# 7400            2016-09-06
# 7401            2016-09-06
# 7402            2016-09-06
#
# [7403 rows x 9 columns]

# %%
# check columns
df['minimum_nights'].head()
df['maximum_nights'].head()
df['minimum_nights'].isnull().sum()
df['maximum_nights'].isnull().sum()
# Out:
# 0

# %%
#check columns
df['calendar_updated'].value_counts()
df['calendar_updated'].isnull().sum()
# Out:
# 0

# %%
df['has_availability'].isnull().sum()
df['has_availability'].value_counts()
#since all the values are true it means that unavalible is false
df['has_availability'] = df['has_availability'].apply(lambda x : 1 if x == 't' else 0)

# %%
#change to datetime format
df['calendar_last_scraped'] = pd.to_datetime(df['calendar_last_scraped'])

# %% [markdown]
# |Feature|Type|Action|
# |---|---|---|
# |**number_of_reviews**|`int64`|clean|
# |**first_review**|`object`|delete due to many missing values|
# |**last_review**|`object`|delete due to many missing values|
# |**review_scores_rating**|`float64`|replace null values with 0|
# |**review_scores_accuracy**|`float64`|replace null values with 0|
# |**review_scores_cleanliness**|`float64`|clean|
# |**review_scores_checkin**|`float64`||
# |**review_scores_communication**|`float64`||
# |**review_scores_location**|`float64`||
# |**review_scores_value**|`float64`||

# %%
df[['number_of_reviews','first_review','last_review','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']]
# Out:
#       number_of_reviews first_review last_review  review_scores_rating  \
# 0                   207   2011-11-01  2016-01-02                  95.0
# 1                    43   2013-08-19  2015-12-29                  96.0
# 2                    20   2014-07-30  2015-09-03                  97.0
# 3                     0          NaN         NaN                   NaN
# 4                    38   2012-07-10  2015-10-24                  92.0
# ...                 ...          ...         ...                   ...
# 7398                  4   2015-09-18  2016-08-27                  90.0
# 7399                  0          NaN         NaN                   NaN
# 7400                  0          NaN         NaN                   NaN
# 7401                  2   2016-08-27  2016-09-04                  90.0
# 7402                  0          NaN         NaN                   NaN
#
#       review_scores_accuracy  review_scores_cleanliness  \
# 0                       10.0                       10.0
# 1                       10.0                       10.0
# 2                       10.0                       10.0
# 3                        NaN                        NaN
# 4                        9.0                        9.0
# ...                      ...                        ...
# 7398                    10.0                       10.0
# 7399                     NaN                        NaN
# 7400                     NaN                        NaN
# 7401                     9.0                        8.0
# 7402                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      10.0                         10.0
# 1                      10.0                         10.0
# 2                      10.0                         10.0
# 3                       NaN                          NaN
# 4                      10.0                         10.0
# ...                     ...                          ...
# 7398                   10.0                         10.0
# 7399                    NaN                          NaN
# 7400                    NaN                          NaN
# 7401                    9.0                          9.0
# 7402                    NaN                          NaN
#
#       review_scores_location  review_scores_value
# 0                        9.0                 10.0
# 1                       10.0                 10.0
# 2                       10.0                 10.0
# 3                        NaN                  NaN
# 4                        9.0                  9.0
# ...                      ...                  ...
# 7398                     8.0                  9.0
# 7399                     NaN                  NaN
# 7400                     NaN                  NaN
# 7401                     8.0                  7.0
# 7402                     NaN                  NaN
#
# [7403 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7403 entries, 0 to 7402
# Data columns (total 75 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                7403 non-null   int64
#  1   scrape_id                         7403 non-null   int64
#  2   last_scraped                      7403 non-null   object
#  3   name                              7403 non-null   object
#  4   host_id                           7403 non-null   int64
#  5   host_name                         7403 non-null   object
#  6   host_since                        7403 non-null   object
#  7   host_location                     7403 non-null   object
#  8   host_response_time                7403 non-null   object
#  9   host_response_rate                7403 non-null   float64
#  10  host_acceptance_rate              7403 non-null   float64
#  11  host_is_superhost                 7403 non-null   int64
#  12  host_listings_count               7403 non-null   int64
#  13  host_total_listings_count         7403 non-null   int64
#  14  host_has_profile_pic              7403 non-null   int64
#  15  host_identity_verified            7403 non-null   int64
#  16  street                            7403 non-null   object
#  17  neighbourhood                     7403 non-null   object
#  18  zipcode                           7403 non-null   object
#  19  smart_location                    7403 non-null   object
#  20  latitude                          7403 non-null   float64
#  21  longitude                         7403 non-null   float64
#  22  is_location_exact                 7403 non-null   int64
#  23  property_type                     7403 non-null   object
#  24  room_type                         7403 non-null   object
#  25  accommodates                      7403 non-null   int64
#  26  bathrooms                         7403 non-null   float64
#  27  bedrooms                          7403 non-null   float64
#  28  beds                              7403 non-null   float64
#  29  bed_type                          7403 non-null   object
#  30  price                             7403 non-null   float64
#  31  security_deposit                  7403 non-null   float64
#  32  cleaning_fee                      7403 non-null   float64
#  33  guests_included                   7403 non-null   int64
#  34  extra_people                      7403 non-null   float64
#  35  minimum_nights                    7403 non-null   int64
#  36  maximum_nights                    7403 non-null   int64
#  37  calendar_updated                  7403 non-null   object
#  38  has_availability                  7403 non-null   int64
#  39  availability_30                   7403 non-null   int64
#  40  availability_60                   7403 non-null   int64
#  41  availability_90                   7403 non-null   int64
#  42  availability_365                  7403 non-null   int64
#  43  calendar_last_scraped             7403 non-null   datetime64[ns]
#  44  number_of_reviews                 7403 non-null   int64
#  45  first_review                      6020 non-null   object
#  46  last_review                       6020 non-null   object
#  47  review_scores_rating              5943 non-null   float64
#  48  review_scores_accuracy            5922 non-null   float64
#  49  review_scores_cleanliness         5932 non-null   float64
#  50  review_scores_checkin             5925 non-null   float64
#  51  review_scores_communication       5934 non-null   float64
#  52  review_scores_location            5926 non-null   float64
#  53  review_scores_value               5926 non-null   float64
#  54  requires_license                  7403 non-null   object
#  55  jurisdiction_names                3818 non-null   object
#  56  instant_bookable                  7403 non-null   object
#  57  cancellation_policy               7403 non-null   object
#  58  require_guest_profile_picture     7403 non-null   object
#  59  require_guest_phone_verification  7403 non-null   object
#  60  calculated_host_listings_count    7403 non-null   int64
#  61  reviews_per_month                 6020 non-null   float64
#  62  access                            2096 non-null   object
#  63  interaction                       2031 non-null   object
#  64  house_rules                       2393 non-null   object
#  65  summary_wc                        7403 non-null   int64
#  66  space_wc                          7403 non-null   int64
#  67  description_wc                    7403 non-null   int64
#  68  neighborhood_overview_wc          7403 non-null   int64
#  69  transit_wc                        7403 non-null   int64
#  70  host_about_wc                     7403 non-null   int64
#  71  notes_wc                          7403 non-null   int64
#  72  host_match                        7403 non-null   int64
#  73  host_verifications_count          7403 non-null   int64
#  74  amenities_count                   7403 non-null   int64
# dtypes: datetime64[ns](1), float64(19), int64(30), object(25)
# memory usage: 4.2+ MB

# %%
missing_heat_map(df)
# Out:
# id : % 0 With 0 missing values
# scrape_id : % 0 With 0 missing values
# last_scraped : % 0 With 0 missing values
# name : % 0 With 0 missing values
# host_id : % 0 With 0 missing values
# host_name : % 0 With 0 missing values
# host_since : % 0 With 0 missing values
# host_location : % 0 With 0 missing values
# host_response_time : % 0 With 0 missing values
# host_response_rate : % 0 With 0 missing values
# host_acceptance_rate : % 0 With 0 missing values
# host_is_superhost : % 0 With 0 missing values
# host_listings_count : % 0 With 0 missing values
# host_total_listings_count : % 0 With 0 missing values
# host_has_profile_pic : % 0 With 0 missing values
# host_identity_verified : % 0 With 0 missing values
# street : % 0 With 0 missing values
# neighbourhood : % 0 With 0 missing values
# zipcode : % 0 With 0 missing values
# smart_location : % 0 With 0 missing values
# latitude : % 0 With 0 missing values
# longitude : % 0 With 0 missing values
# is_location_exact : % 0 With 0 missing values
# property_type : % 0 With 0 missing values
# room_type : % 0 With 0 missing values
# accommodates : % 0 With 0 missing values
# bathrooms : % 0 With 0 missing values
# bedrooms : % 0 With 0 missing values
# beds : % 0 With 0 missing values
# bed_type : % 0 With 0 missing values
# price : % 0 With 0 missing values
# security_deposit : % 0 With 0 missing values
# cleaning_fee : % 0 With 0 missing values
# guests_included : % 0 With 0 missing values
# extra_people : % 0 With 0 missing values
# minimum_nights : % 0 With 0 missing values
# maximum_nights : % 0 With 0 missing values
# calendar_updated : % 0 With 0 missing values
# has_availability : % 0 With 0 missing values
# availability_30 : % 0 With 0 missing values
# availability_60 : % 0 With 0 missing values
# availability_90 : % 0 With 0 missing values
# availability_365 : % 0 With 0 missing values
# calendar_last_scraped : % 0 With 0 missing values
# number_of_reviews : % 0 With 0 missing values
# first_review : % 18 With 1383 missing values
# last_review : % 18 With 1383 missing values
# review_scores_rating : % 19 With 1460 missing values
# review_scores_accuracy : % 20 With 1481 missing values
# review_scores_cleanliness : % 19 With 1471 missing values
# review_scores_checkin : % 19 With 1478 missing values
# review_scores_communication : % 19 With 1469 missing values
# review_scores_location : % 19 With 1477 missing values
# review_scores_value : % 19 With 1477 missing values
# requires_license : % 0 With 0 missing values
# jurisdiction_names : % 48 With 3585 missing values
# instant_bookable : % 0 With 0 missing values
# cancellation_policy : % 0 With 0 missing values
# require_guest_profile_picture : % 0 With 0 missing values
# require_guest_phone_verification : % 0 With 0 missing values
# calculated_host_listings_count : % 0 With 0 missing values
# reviews_per_month : % 18 With 1383 missing values
# access : % 71 With 5307 missing values
# interaction : % 72 With 5372 missing values
# house_rules : % 67 With 5010 missing values
# summary_wc : % 0 With 0 missing values
# space_wc : % 0 With 0 missing values
# description_wc : % 0 With 0 missing values
# neighborhood_overview_wc : % 0 With 0 missing values
# transit_wc : % 0 With 0 missing values
# host_about_wc : % 0 With 0 missing values
# notes_wc : % 0 With 0 missing values
# host_match : % 0 With 0 missing values
# host_verifications_count : % 0 With 0 missing values
# amenities_count : % 0 With 0 missing values
